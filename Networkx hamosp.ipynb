# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HomoSapiens_cocomp_all.txt",sep="\t",usecols=["Uniprot_A","Uniprot_B"])

# %%
df.head()
# Out:
#     Uniprot_A Uniprot_B
# 0  A0A024QYV7    B4DJ51
# 1  A0A024QYV7    O60216
# 2  A0A024QYV7    P0CG48
# 3  A0A024QYV7    P16455
# 4  A0A024QYV7    P35558

# %%
G=nx.from_pandas_edgelist(df,"Uniprot_A","Uniprot_B",create_using=nx.DiGraph())

# %%
print(G)
# Out:
# DiGraph with 18209 nodes and 387377 edges

# %%
print(G.degree())
# Out:
# [('A0A024QYV7', 13), ('B4DJ51', 224), ('O60216', 258), ('P0CG48', 8494), ('P16455', 82), ('P35558', 86), ('P40337', 512), ('P51858', 213), ('P63104', 871), ('Q00653', 190), ('Q15004', 815), ('Q15843', 342), ('Q99558', 224), ('Q9Y6K9', 451), ('A0A024QZR3', 1), ('Q5S007', 2109), ('A0A024QZY1', 1), ('A0A024R087', 4), ('P61956', 1332), ('Q15014', 100), ('Q9UBU8', 97), ('A0A024R1A3', 1), ('A0A024R3C9', 3), ('P53355', 142), ('Q14847', 79), ('Q9NPD8', 28), ('A0A024R5U4', 119), ('O00217', 59), ('O14548', 15), ('O14925', 43), ('O14949', 48), ('O43169', 34), ('O43615', 72), ('O43676', 30), ('O43678', 38), ('O43819', 62), ('O43920', 68), ('O60488', 65), ('O75208', 225), ('O75251', 112), ('O75306', 106), ('O75380', 102), ('O75438', 18), ('O75439', 94), ('O75489', 247), ('O75947', 97), ('O95168', 41), ('O95182', 41), ('O95202', 54), ('O95299', 65), ('O95563', 19), ('P00387', 66), ('P01308', 471), ('P09669', 42), ('P10176', 5), ('P11047', 40), ('P12074', 22), ('P12236', 223), ('P14406', 39), ('P14735', 78), ('P14927', 44), ('P15954', 6), ('P18859', 57), ('P19404', 47), ('P20674', 68), ('P22695', 114), ('P22830', 56), ('P23786', 27), ('P24539', 109), ('P28288', 126), ('P28331', 113), ('P33121', 18), ('P36542', 167), ('P47985', 50), ('P48047', 144), ('P49821', 66), ('P51970', 81), ('P52789', 56), ('P53007', 185), ('P53701', 62), ('P53985', 98), ('P56381', 38), ('P56385', 43), ('P56556', 64), ('P60602', 7), ('Q00325', 207), ('Q07021', 361), ('Q07812', 99), ('Q10713', 88), ('Q13011', 215), ('Q13085', 122), ('Q13232', 42), ('Q13423', 44), ('Q15286', 50), ('Q16718', 77), ('Q16795', 124), ('Q16891', 167), ('Q3ZCQ8', 191), ('Q5JRX3', 39), ('Q5RI15', 21), ('Q6IAN0', 34), ('Q6P4A7', 39), ('Q6UXV4', 59), ('Q7L0Y3', 87), ('Q86SX6', 28), ('Q86Y39', 53), ('Q8N183', 20), ('Q8NI60', 76), ('Q8TC12', 42), ('Q8WWC4', 112), ('Q8WWV3', 20), ('Q969Z0', 54), ('Q96BW9', 36), ('Q96IX5', 64), ('Q96RQ3', 60), ('Q9BPW8', 97), ('Q9BRT2', 29), ('Q9BU61', 40), ('Q9BUB7', 32), ('Q9BVV7', 33), ('Q9H078', 91), ('Q9H4A6', 52), ('Q9H7Z7', 26), ('Q9H845', 96), ('Q9H9B4', 220), ('Q9NQE9', 10), ('Q9NRV9', 8), ('Q9NVI7', 321), ('Q9NX63', 108), ('Q9NZJ7', 34), ('Q9P032', 74), ('Q9P0J0', 92), ('Q9UDW1', 27), ('Q9UI09', 70), ('Q9UJZ1', 118), ('Q9Y2R0', 58), ('Q9Y2S7', 110), ('Q9Y3D6', 22), ('Q9Y3D7', 33), ('Q9Y4W6', 108), ('Q9Y512', 55), ('Q9Y5J9', 28), ('Q9Y697', 51), ('Q9Y6C9', 123), ('Q9Y6H1', 163), ('Q9Y6M9', 32), ('A0A024R687', 1), ('A0A024R6D8', 1), ('A0A024R718', 1), ('A0A024R7T3', 1), ('A0A024R7V6', 1), ('Q8TB24', 502), ('A0A024R821', 1), ('O75807', 204), ('A0A024R8A7', 1), ('A0A024R8E4', 1), ('A0A024R8U5', 1), ('A0A024R8W0', 1), ('A0A024R9F6', 4), ('Q7Z406', 89), ('Q96JM7', 36), ('Q96JN0', 74), ('Q9H9G7', 86), ('A0A024RA58', 1), ('A0A024RAE1', 1), ('A0A024RAZ7', 2), ('P67809', 493), ('A0A024RB16', 1), ('A0A024RBF6', 1), ('A0A024RC46', 2), ('P03372', 2211), ('Q92731', 2440), ('A0A024RCN6', 1), ('A0A024RCN7', 1), ('P13569', 1106), ('A0A024RDJ1', 1), ('A0A024RDV9', 1), ('A0A024RDY0', 1), ('A0A059RUZ1', 48), ('O43663', 892), ('O60885', 1332), ('O94972', 364), ('O95831', 373), ('P00533', 1356), ('P01106', 1965), ('P02751', 735), ('P11234', 62), ('P18433', 64), ('P21796', 295), ('P24941', 654), ('P27105', 141), ('P35232', 911), ('P35610', 187), ('P49116', 1350), ('P61586', 244), ('P78317', 1282), ('P83105', 185), ('Q13263', 1081), ('Q13794', 172), ('Q14197', 268), ('Q14999', 775), ('Q15029', 1352), ('Q16659', 309), ('Q16849', 68), ('Q5BJD5', 130), ('Q5JTJ3', 15), ('Q69YN4', 2754), ('Q6NUN9', 286), ('Q6UX01', 941), ('Q86VM9', 805), ('Q8IXH7', 48), ('Q96CS3', 276), ('Q96TA2', 76), ('Q9BVJ7', 85), ('Q9BXW9', 712), ('Q9H4D1', 326), ('Q9HCE5', 345), ('Q9NZ94', 29), ('Q9NZC7', 467), ('Q9P0S2', 9), ('U5YWV7', 29), ('A0A075B6P5', 1), ('P17813', 210), ('A0A075B6P9', 2), ('P27695', 999), ('P31943', 1165), ('A0A075B6R9', 1), ('Q9C0B5', 492), ('A0A075B6S6', 1), ('Q16526', 202), ('A0A075B759', 1), ('P0DN37', 20), ('A0A087WT10', 1), ('A0A087WWS6', 7), ('O94842', 77), ('P01562', 19), ('P01568', ...

# %%
degrees
# Out:
# {'A0A024QYV7': 13,
#  'B4DJ51': 224,
#  'O60216': 258,
#  'P0CG48': 8494,
#  'P16455': 82,
#  'P35558': 86,
#  'P40337': 512,
#  'P51858': 213,
#  'P63104': 871,
#  'Q00653': 190,
#  'Q15004': 815,
#  'Q15843': 342,
#  'Q99558': 224,
#  'Q9Y6K9': 451,
#  'A0A024QZR3': 1,
#  'Q5S007': 2109,
#  'A0A024QZY1': 1,
#  'A0A024R087': 4,
#  'P61956': 1332,
#  'Q15014': 100,
#  'Q9UBU8': 97,
#  'A0A024R1A3': 1,
#  'A0A024R3C9': 3,
#  'P53355': 142,
#  'Q14847': 79,
#  'Q9NPD8': 28,
#  'A0A024R5U4': 119,
#  'O00217': 59,
#  'O14548': 15,
#  'O14925': 43,
#  'O14949': 48,
#  'O43169': 34,
#  'O43615': 72,
#  'O43676': 30,
#  'O43678': 38,
#  'O43819': 62,
#  'O43920': 68,
#  'O60488': 65,
#  'O75208': 225,
#  'O75251': 112,
#  'O75306': 106,
#  'O75380': 102,
#  'O75438': 18,
#  'O75439': 94,
#  'O75489': 247,
#  'O75947': 97,
#  'O95168': 41,
#  'O95182': 41,
#  'O95202': 54,
#  'O95299': 65,
#  'O95563': 19,
#  'P00387': 66,
#  'P01308': 471,
#  'P09669': 42,
#  'P10176': 5,
#  'P11047': 40,
#  'P12074': 22,
#  'P12236': 223,
#  'P14406': 39,
#  'P14735': 78,
#  'P14927': 44,
#  'P15954': 6,
#  'P18859': 57,
#  'P19404': 47,
#  'P20674': 68,
#  'P22695': 114,
#  'P22830': 56,
#  'P23786': 27,
#  'P24539': 109,
#  'P28288': 126,
#  'P28331': 113,
#  'P33121': 18,
#  'P36542': 167,
#  'P47985': 50,
#  'P48047': 144,
#  'P49821': 66,
#  'P51970': 81,
#  'P52789': 56,
#  'P53007': 185,
#  'P53701': 62,
#  'P53985': 98,
#  'P56381': 38,
#  'P56385': 43,
#  'P56556': 64,
#  'P60602': 7,
#  'Q00325': 207,
#  'Q07021': 361,
#  'Q07812': 99,
#  'Q10713': 88,
#  'Q13011': 215,
#  'Q13085': 122,
#  'Q13232': 42,
#  'Q13423': 44,
#  'Q15286': 50,
#  'Q16718': 77,
#  'Q16795': 124,
#  'Q16891': 167,
#  'Q3ZCQ8': 191,
#  'Q5JRX3': 39,
#  'Q5RI15': 21,
#  'Q6IAN0': 34,
#  'Q6P4A7': 39,
#  'Q6UXV4': 59,
#  'Q7L0Y3': 87,
#  'Q86SX6': 28,
#  'Q86Y39': 53,
#  'Q8N183': 20,
#  'Q8NI60': 76,
#  'Q8TC12': 42,
#  'Q8WWC4': 112,
#  'Q8WWV3': 20,
#  'Q969Z0': 54,
#  'Q96BW9': 36,
#  'Q96IX5': 64,
#  'Q96RQ3': 60,
#  'Q9BPW8': 97,
#  'Q9BRT2': 29,
#  'Q9BU61': 40,
#  'Q9BUB7': 32,
#  'Q9BVV7': 33,
#  'Q9H078': 91,
#  'Q9H4A6': 52,
#  'Q9H7Z7': 26,
#  'Q9H845': 96,
#  'Q9H9B4': 220,
#  'Q9NQE9': 10,
#  'Q9NRV9': 8,
#  'Q9NVI7': 321,
#  'Q9NX63': 108,
#  'Q9NZJ7': 34,
#  'Q9P032': 74,
#  'Q9P0J0': 92,
#  'Q9UDW1': 27,
#  'Q9UI09': 70,
#  'Q9UJZ1': 118,
#  'Q9Y2R0': 58,
#  'Q9Y2S7': 110,
#  'Q9Y3D6': 22,
#  'Q9Y3D7': 33,
#  'Q9Y4W6': 108,
#  'Q9Y512': 55,
#  'Q9Y5J9': 28,
#  'Q9Y697': 51,
#  'Q9Y6C9': 123,
#  'Q9Y6H1': 163,
#  'Q9Y6M9': 32,
#  'A0A024R687': 1,
#  'A0A024R6D8': 1,
#  'A0A024R718': 1,
#  'A0A024R7T3': 1,
#  'A0A024R7V6': 1,
#  'Q8TB24': 502,
#  'A0A024R821': 1,
#  'O75807': 204,
#  'A0A024R8A7': 1,
#  'A0A024R8E4': 1,
#  'A0A024R8U5': 1,
#  'A0A024R8W0': 1,
#  'A0A024R9F6': 4,
#  'Q7Z406': 89,
#  'Q96JM7': 36,
#  'Q96JN0': 74,
#  'Q9H9G7': 86,
#  'A0A024RA58': 1,
#  'A0A024RAE1': 1,
#  'A0A024RAZ7': 2,
#  'P67809': 493,
#  'A0A024RB16': 1,
#  'A0A024RBF6': 1,
#  'A0A024RC46': 2,
#  'P03372': 2211,
#  'Q92731': 2440,
#  'A0A024RCN6': 1,
#  'A0A024RCN7': 1,
#  'P13569': 1106,
#  'A0A024RDJ1': 1,
#  'A0A024RDV9': 1,
#  'A0A024RDY0': 1,
#  'A0A059RUZ1': 48,
#  'O43663': 892,
#  'O60885': 1332,
#  'O94972': 364,
#  'O95831': 373,
#  'P00533': 1356,
#  'P01106': 1965,
#  'P02751': 735,
#  'P11234': 62,
#  'P18433': 64,
#  'P21796': 295,
#  'P24941': 654,
#  'P27105': 141,
#  'P35232': 911,
#  'P35610': 187,
#  'P49116': 1350,
#  'P61586': 244,
#  'P78317': 1282,
#  'P83105': 185,
#  'Q13263': 1081,
#  'Q13794': 172,
#  'Q14197': 268,
#  'Q14999': 775,
#  'Q15029': 1352,
#  'Q16659': 309,
#  'Q16849': 68,
#  'Q5BJD5': 130,
#  'Q5JTJ3': 15,
#  'Q69YN4': 2754,
#  'Q6NUN9': 286,
#  'Q6UX01': 941,
#  'Q86VM9': 805,
#  'Q8IXH7': 48,
#  'Q96CS3': 276,
#  'Q96TA2': 76,
#  'Q9BVJ7': 85,
#  'Q9BXW9': 712,
#  'Q9H4D1': 326,
#  'Q9HCE5': 345,
#  'Q9NZ94': 29,
#  'Q9NZC7': 467,
#  'Q9P0S2': 9,
#  'U5YWV7': 29,
#  'A0A075B6P5': 1,
#  'P17813': 210,
#  'A0A075B6P9': 2,
#  'P27695': 999,
#  'P31943': 1165,
#  'A0A075B6R9': 1,
#  'Q9C0B5': 492,
#  'A0A075B6S6': 1,
#  'Q16526': 202,
#  'A0A075B759': 1,
#  'P0DN37': 20,
#  'A0A087WT10': 1,
#  'A0A087WWS6': 7,
#  'O94842': 77,
#  'P01562': 19,
#  'P01568': 26,
#  'P01569': 16,
#  'P05014': 10,
#  'P32881': 11,
#  'Q9NXT0': 5,
#  'A0A087WXA3': 3,
#  'O95786': 1636,
#  'Q14258': 2144,
#  'A0A087WZU1': 8,
#  'O14745': 66,
#  'P15311': 304,
#  'Q01814': 122,
#  'Q15075': 87,
#  'Q15599': 66,
#  'Q8N157': 45,
#  'Q8WXW3': 55,
#  'Q96L92': 91,
#  'A0A087X1V8': 1,
#  'P56945': 698,
#  'A0A096LP49': 1,
#  'Q9Y2H1': 141,
#  'A0A096LPI6': 1,
#  'A0A0A6YYA0': 4,
#  'O15530': 119,
#  'P20339': 282,
#  'A0A0A6YYB9': 1,
#  'A0A0A6YYG8': 1,
#  'A0A0A6YYG9': 9,
#  'Q01995': 298,
#  'Q13489': 1324,
#  'Q9UBU9': 1123,
#  'Q9UBX2': 257,
#  'A0A0A6YYH1': 1,
#  'A0A0A6YYI9': 34,
#  'O75147': 843,
#  'O75351': 31,
#  'O75843': 25,
#  'O95395': 8,
#  'O95704': 22,
#  'P00740': 35,
#  'P13473': 90,
#  'P28335': 98,
#  'P48052': 8,
#  'P57081': 22,
#  'Q13363': 158,
#  'Q14004': 70,
#  'Q14451': 88,
#  'Q14839': 692,
#  'Q15022': 591,
#  'Q15527': 34,
#  'Q4G0J3': 897,
#  'Q53GT1': 55,
#  'Q8N5Z5': 68,
#  'Q8N6T7': 184,
#  'Q96EP0': 322,
#  'Q96EX3': 39,
#  'Q9BTE6': 57,
#  'Q9H5K3': 75,
#  'Q9H813': 97,
#  'Q9H8J5': 90,
#  'Q9UIV8': 26,
#  'Q9Y2I8': 55,
#  'Q9Y4K0': 34,
#  'Q9Y6X3': 122,
#  'A0A0A6YYL0': 3,
#  'A0A0A6YYL4': 1,
#  'A0A0A6YYL6': 5,
#  'P42166': 419,
#  'P49711': 189,
#  'A0A0B4J1V8': 45,
#  'O15213': 118,
#  'O95793': 786,
#  'P01127': 76,
#  'P04908': 374,
#  'P06748': 728,
#  'P10074': 81,
#  'P10412': 181,
#  'P15880': 277,
#  'P26373': 243,
#  'P33778': 319,
#  'P42696': 163,
#  'P46779': 197,
#  'P50914': 244,
#  'P55075': 98,
#  'P61513': 199,
#  'P62263': 276,
#  'P62633': 186,
#  'P62805': 1614,
#  'P62888': 244,
#  'Q02543': 223,
#  'Q07020': 278,
#  'Q12905': 285,
#  'Q15020': 179,
#  'Q53GL0': 50,
#  'Q5T3I0': 141,
#  'Q5TC82': 605,
#  'Q7RTS1': 44,
#  'Q7Z2W4': 234,
#  'Q8IXZ2': 125,
#  'Q96HE9': 99,
#  'Q96ME7': 108,
#  'Q99496': 738,
#  'Q9BRS2': 461,
#  'Q9BSG1': 71,
#  'Q9BWF3': 170,
#  'Q9BXY0': 79,
#  'Q9BYG3': 163,
#  'Q9HBD1': 600,
#  'Q9NQ55': 155,
#  'Q9P0M6': 129,
#  'Q9UGY1': 86,
#  'A0A0B4J269': 8,
#  'P19438': 238,
#  'P20333': 127,
#  'Q04206': 445,
#  'Q13233': 153,
#  'Q99759': 197,
#  'Q9H079': 20,
#  'Q9Y4K3': 601,
#  'A0A0B4J2A2': 2,
#  'Q99956': 90,
#  'A0A0B4J2F0': 3,
#  'Q96S66': 44,
#  'A0A0K0K1K4': 1,
#  'A0A0K0K1K7': 1,
#  'A0A0K2S4Q6': 2,
#  'O43914': 17,
#  'Q9UBK5': 4,
#  'A0A0M3HEQ9': 1,
#  'A0A0S2Z4R1': 1,
#  'A0A0U1RRH7': 1,
#  'A0A0X9T7T4': 1,
#  'A0A109NGN6': 1,
#  'A0A140VJF4': 1,
#  'A0A140VJK1': 1,
#  'A0A140VJL3': 1,
#  'A0A140VJP2': 1,
#  'A0A140VJR2': 1,
#  'A0A140VJS0': 1,
#  'A0A140VJT0': 1,
#  'A0A140VJT2': 1,
#  'A0A140VJT8': 1,
#  'A0A140VJW5': 1,
#  'A0A140VJX1': 1,
#  'A0A140VJY2': 1,
#  'A0A140VJZ1': 1,
#  'A0A140VJZ4': 1,
#  'A0A140VK27': 1,
#  'A0A140VK41': 1,
#  'A0A140VK53': 2,
#  'A0A140VK56': 1,
#  'A0A140VK69': 1,
#  'A0A140VK70': 1,
#  'A0A140VKA6': 1,
#  'A0A140VKE7': 1,
#  'A0A140VKF1': 1,
#  'A0A183YE00': 1,
#  'Q8NBM4': 77,
#  'A0A1B0GVH7': 2,
#  'P25440': 228,
#  'Q15058': 1698,
#  'A0A1U9X7U3': 1,
#  'A0A1U9X8P6': 1,
#  'A0A1W2PQS6': 5,
#  'Q02790': 119,
#  'A0A286YEY3': 1,
#  'A0A2R8Y422': 1,
#  'P49407': 289,
#  'A0A2U3TZM3': 5,
#  'Q7Z6J9': 10,
#  'Q8NCE0': 21,
#  'Q92989': 24,
#  'Q9BSV6': 18,
#  'A0AV02': 2,
#  'Q8N5V2': 54,
#  'A0AV96': 12,
#  'O14578': 1366,
#  'P55916': 11,
#  'Q13315': 178,
#  'Q15717': 1846,
#  'Q9H8V3': 815,
#  'A0AVF1': 31,
#  'O14980': 1237,
#  'O60303': 128,
#  'O94761': 1345,
#  'P08151': 104,
#  'P30305': 109,
#  'P52790': 20,
#  'P55072': 789,
#  'Q13099': 53,
#  'Q16825': 64,
#  'Q3KP44': 204,
#  'Q3SXY8': 30,
#  'Q86VQ0': 116,
#  'Q86WT1': 28,
#  'Q8IY31': 44,
#  'Q8N4P2': 48,
#  'Q8NAF0': 27,
#  'Q8TAT6': 81,
#  'Q8WYA0': 46,
#  'Q92890': 72,
#  'Q96AJ1': 218,
#  'Q96LB3': 63,
#  'Q96LJ8': 39,
#  'Q9BW83': 51,
#  'Q9H7X7': 29,
#  'Q9NQC8': 27,
#  'Q9NWB7': 61,
#  'Q9P2H3': 25,
#  'Q9UG01': 38,
#  'Q9Y366': 29,
#  'Q9Y547': 24,
#  'A0AVI4': 26,
#  'O75131': 51,
#  'O75165': 65,
#  'P04439': 150,
#  'P50213': 41,
#  'P51571': 120,
#  'P51668': 169,
#  'P55899': 63,
#  'P61077': 159,
#  'Q13370': 38,
#  'Q86TM6': 135,
#  'Q8N2K1': 15,
#  'Q8TAD4': 29,
#  'Q96JJ7': 44,
#  'Q9BQE4': 31,
#  'Q9BSJ8': 87,
#  'Q9BUN8': 129,
#  'Q9BZX2': 25,
#  'Q9GZP9': 48,
#  'Q9UBV2': 74,
#  'Q9Y2L1': 92,
#  'Q9Y4L1': 105,
#  'A0AVK6': 6,
#  'P05067': 2372,
#  'P41002': 31,
#  'P51957': 555,
#  'Q15233': 294,
#  'Q6PID6': 31,
#  'Q96AV8': 28,
#  'A0AVT1': 42,
#  'O00308': 727,
#  'O15205': 29,
#  'O95221': 10,
#  'P04629': 1958,
#  'P14866': 1603,
#  'P25791': 82,
#  'P29084': 122,
#  'P36952': 82,
#  'P38919': 324,
#  'P42331': 47,
#  'P43353': 34,
#  'P51114': 165,
#  'P60604': 35,
#  'P62837': 208,
#  'P68036': 136,
#  'Q06787': 137,
#  'Q16763': 69,
#  'Q8WUD1': 35,
#  'Q8WVK2': 124,
#  'Q8WY64': 22,
#  'Q96J02': 222,
#  'Q96QD9': 87,
#  'Q9H0W5': 589,
#  'Q9H832': 18,
#  'Q9NR09': 89,
#  'Q9NRZ9': 98,
#  'Q9NWS0': 682,
#  'Q9NZN9': 18,
#  'Q9P267': 19,
#  'Q9Y6Q1': 14,
#  'A0FGR8': 63,
#  'A0FGR9': 7,
#  'O00472': 29,
#  'O00567': 309,
#  'O15118': 306,
#  'O15155': 276,
#  'O75787': 122,
#  'O95183': 73,
#  'P04637': 1730,
#  'P09466': 12,
#  'P14672': 43,
#  'P27824': 578,
#  'P43699': 162,
#  'P98174': 33,
#  'Q13286': 96,
#  'Q14653': 129,
#  'Q15077': 370,
#  'Q16829': 61,
#  'Q71U36': 531,
#  'Q86X19': 400,
#  'Q8IWL3': 702,
#  'Q8IY34': 227,
#  'Q8N697': 49,
#  'Q8TD08': 22,
#  'Q92542': 92,
#  'Q96RR4': 36,
#  'Q99549': 67,
#  'Q9BQ67': 309,
#  'Q9BQE3': 306,
#  'Q9H1C4': 355,
#  'Q9H1X3': 54,
#  'Q9H4M7': 2928,
#  'Q9NQW6': 933,
#  'Q9UGP8': 96,
#  'Q9UHD9': 501,
#  'Q9UI95': 273,
#  'Q9UKV8': 363,
#  'Q9UMX0': 134,
#  'Q9Y5B0': 167,
#  'Q01844': 294,
#  'Q13619': 724,
#  'A0JLT2': 135,
#  'B4DUB1': 33,
#  'O00571': 286,
#  'O14645': 13,
#  'O15042': 119,
#  'O15514': 94,
#  'O43513': 66,
#  'O60244': 106,
#  'O75448': 84,
#  'O75586': 85,
#  'O76021': 131,
#  'O95071': 345,
#  'O95104': 61,
#  'O95232': 93,
#  'O95402': 115,
#  'O95714': 387,
#  'O95816': 290,
#  'P02545': 464,
#  'P02652': 32,
#  'P0CAP2': 87,
#  'P10809': 635,
#  'P15976': 50,
#  'P17480': 109,
#  'P19387': 164,
#  'P19388': 181,
#  'P22087': 426,
#  'P24863': 62,
#  'P24928': 347,
#  'P26599': 195,
#  'P30876': 215,
#  'P31689': 307,
#  'P34931': 212,
#  'P36954': 91,
#  'P38646': 392,
#  'P46060': 122,
#  'P49336': 213,
#  'P50570': 123,
#  'P51610': 166,
#  'P52272': 284,
#  'P52292': 224,
#  'P52434': 137,
#  'P52435': 98,
#  'P53803': 62,
#  'P60842': 188,
#  'P61218': 93,
#  'P62314': 180,
#  'P62487': 119,
#  'P62875': 91,
#  'P68104': 296,
#  'P84103': 157,
#  'Q13148': 404,
#  'Q13427': 40,
#  'Q13428': 115,
#  'Q13503': 129,
#  'Q13523': 140,
#  'Q13838': 324,
#  'Q14498': 860,
#  'Q14978': 144,
#  'Q14980': 146,
#  'Q15287': 236,
#  'Q15528': 60,
#  'Q15648': 132,
#  'Q15796': 262,
#  'Q15797': 165,
#  'Q16531': 394,
#  'Q16637': 181,
#  'Q3L8U1': 35,
#  'Q5T200': 69,
#  'Q5VT52': 88,
#  'Q6P2C8': 69,
#  'Q709F0': 94,
#  'Q71F56': 56,
#  'Q71SY5': 50,
#  'Q76FK4': 40,
#  'Q86YW9': 38,
#  'Q8IXW5': 120,
#  'Q8TBK6': 11,
#  'Q8TEX9': 91,
#  'Q8WYP5': 53,
#  'Q8WZ42': 81,
#  'Q92616': 186,
#  'Q93074': 145,
#  'Q969H0': 286,
#  'Q96C00': 20,
#  'Q96G25': 83,
#  'Q96HR3': 67,
#  'Q96RN5': 75,
#  'Q9BQ39': 101,
#  'Q9BQ75': 45,
#  'Q9BQG0': 200,
#  'Q9BTT4': 91,
#  'Q9BUE0': 63,
#  'Q9BVI4': 65,
#  'Q9BWU1': 67,
#  'Q9H1A4': 103,
#  'Q9H204': 88,
#  'Q9H307': 157,
#  'Q9H444': 645,
#  'Q9H8H2': 117,
#  'Q9H944': 152,
#  'Q9NPJ6': 398,
#  'Q9NR30': 233,
#  'Q9NTJ3': 121,
#  'Q9NVC6': 109,
#  'Q9NWA0': 105,
#  'Q9NX70': 107,
#  'Q9P086': 49,
#  'Q9UBN7': 347,
#  'Q9UHB7': 48,
#  'Q9UHI6': 134,
#  'Q9UHV7': 72,
#  'Q9UJX2': 99,
#  'Q9UJX4': 79,
#  'Q9UJX6': 65,
#  'Q9UKV3': 128,
#  'Q9ULK4': 179,
#  'Q9ULT8': 145,
#  'Q9Y265': 376,
#  'Q9Y2R4': 77,
#  'Q9Y2X0': 86,
#  'Q9Y2X3': 137,
#  'Q9Y2X9': 78,
#  'Q9Y3C7': 58,
#  'A0JNW5': 21,
#  'O14593': 51,
#  'O43493': 456,
#  'P26358': 155,
#  'P31946': 577,
#  'P49356': 52,
#  'P63167': 230,
#  'Q0D2I5': 25,
#  'Q53SF7': 28,
#  'Q7L591': 16,
#  'Q86UX7': 46,
#  'Q8IY63': 69,
#  'Q8TBP5': 47,
#  'Q8WUE5': 17,
#  'Q92930': 45,
#  'Q9BWV3': 9,
#  'Q9HCK8': 94,
#  'Q9UN30': 38,
#  'A0JP26': 26,
#  'A5A3E0': 82,
#  'B2RU33': 9,
#  'H3BUK9': 4,
#  'O43747': 65,
#  'O60749': 60,
#  'O75330': 47,
#  'O75496': 69,
#  'P07951': 102,
#  'P14373': 129,
#  'P36406': 34,
#  'P39880': 69,
#  'P48729': 255,
#  'P56377': 42,
#  'Q01850': 32,
#  'Q13596': 61,
#  'Q14008': 143,
#  'Q14155': 78,
#  'Q5T0W9': 37,
#  'Q86YR6': 2,
#  'Q8ND83': 13,
#  'Q93009': 388,
#  'Q9H4H8': 39,
#  'Q9UNH7': 65,
#  'Q9UPQ7': 15,
#  'Q9UQR0': 28,
#  'Q9Y2X7': 71,
#  'A0M8Q6': 4,
#  'B9A064': 35,
#  'P27348': 674,
#  'Q05086': 284,
#  'A0M8Q9': 1,
#  'Q9H081': 67,
#  'A0MNP0': 2,
#  'A6NE76': 50,
#  'A0MNP2': 21,
#  'O43172': 159,
#  'O75533': 239,
#  'O75643': 253,
#  'O94906': 150,
#  'O95400': 150,
#  'P08579': 107,
#  'P10276': 169,
#  'P29590': 253,
#  'P43360': 45,
#  'P61964': 261,
#  'Q53GS9': 101,
#  'Q6P2Q9': 603,
#  'Q8IYB3': 215,
#  'Q9BUQ8': 116,
#  'Q9UHV9': 140,
#  'A0MZ66': 18,
#  'P06276': 29,
#  'P46934': 372,
#  'P49757': 66,
#  'P56539': 54,
#  'P61981': 643,
#  'Q8IV03': 10,
#  'Q8N448': 18,
#  'Q8TBB1': 123,
#  'Q96KS9': 48,
#  'Q9GZM8': 70,
#  'Q9H4P4': 87,
#  'Q9NP64': 48,
#  'A0N0R2': 3,
#  'P04899': 126,
#  'P09471': 50,
#  'P50148': 83,
#  'A0N4V7': 10,
#  'O00141': 92,
#  'O75365': 126,
#  'O75688': 99,
#  'P62330': 183,
#  'Q38SD2': 97,
#  'Q99623': 246,
#  'Q9NS64': 7,
#  'Q9UFF9': 47,
#  'Q9Y6J8': 45,
#  'A0PJ86': 1,
#  'A0PJE2': 2,
#  'B2R4P9': 66,
#  'P84243': 156,
#  'A0PJH2': 2,
#  'A0PJW6': 34,
#  'O00322': 81,
#  'O00560': 90,
#  'O14763': 72,
#  'P08473': 131,
#  'P10321': 149,
#  'P22460': 52,
#  'P23468': 66,
#  'P30825': 70,
#  'P32297': 32,
#  'P32929': 28,
#  'P35670': 22,
#  'P42898': 30,
#  'P48960': 55,
#  'P54707': 55,
#  'Q13061': 41,
#  'Q15116': 53,
#  'Q5BVD1': 8,
#  'Q6ZMH5': 45,
#  'Q86UE6': 38,
#  'Q8NFQ8': 81,
#  'Q8WTR2': 80,
#  'Q8WXA8': 82,
#  'Q92633': 147,
#  'Q9GZM5': 96,
#  'Q9H8X2': 100,
#  'Q9P2N5': 53,
#  'Q9UN74': 25,
#  'Q9Y282': 80,
#  'Q9Y5I4': 36,
#  'A0PJX0': 2,
#  'P0CG47': 276,
#  'Q9UHR6': 63,
#  'A0PJX2': 6,
#  'P21281': 45,
#  'P21283': 18,
#  'P36543': 25,
#  'Q96M94': 55,
#  'Q9Y5K8': 29,
#  'A0PJY2': 1,
#  'P24046': 8,
#  'A0PJZ3': 9,
#  'A4D1S0': 48,
#  'P20036': 96,
#  'P32970': 84,
#  'Q03721': 29,
#  'Q13296': 75,
#  'Q9UBM8': 34,
#  'Q9Y4Z2': 42,
#  'A0PK00': 24,
#  'P16444': 56,
#  'Q15155': 30,
#  'Q16581': 92,
#  'Q16799': 25,
#  'Q6NUS6': 317,
#  'Q6P5W5': 102,
#  'Q969V3': 46,
#  'Q96GX1': 279,
#  'Q99679': 73,
#  'Q9BXJ8': 19,
#  'Q9H1A3': 25,
#  'Q9NRX5': 36,
#  'Q9NRZ7': 26,
#  'Q9NXU5': 24,
#  'Q9UGM1': 72,
#  'Q9UHP7': 74,
#  'A0ZT98': 2,
#  'P36897': 235,
#  'P37173': 159,
#  'A1A4G5': 7,
#  'P07948': 254,
#  'P30260': 154,
#  'P78406': 137,
#  'Q12834': 184,
#  'Q9UJX5': 89,
#  'Q9UM11': 146,
#  'Q9UM13': 42,
#  'A1A4S6': 19,
#  'O15047': 117,
#  'P01112': 159,
#  'P46013': 498,
#  'Q05209': 79,
#  'Q6P5Z2': 84,
#  'Q8N3Y1': 134,
#  'Q9C009': 107,
#  'Q9ULB1': 9,
#  'Q9UNA1': 51,
#  'Q9Y426': 8,
#  'A1A4V9': 2,
#  'O95969': 11,
#  'P34897': 472,
#  'A1A4Y4': 15,
#  'O15455': 41,
#  'O75385': 101,
#  'Q14457': 179,
#  'Q676U5': 730,
#  'Q6ZNE5': 45,
#  'Q9BXW4': 73,
#  'Q9C0C7': 212,
#  'Q9H0Y0': 22,
#  'Q9H1Y0': 120,
#  'Q9HC29': 84,
#  'Q9Y239': 37,
#  'Q9Y371': 62,
#  'A1A519': 14,
#  'O14777': 70,
#  'O95292': 171,
#  'Q2KHR3': 32,
#  'Q8N108': 31,
#  'Q8N752': 34,
#  'Q8NBT2': 45,
#  'Q96DF8': 45,
#  'Q9H7S9': 39,
#  'Q9HBM1': 41,
#  'Q9NW07': 5,
#  'Q9P0L0': 259,
#  'A1A5B4': 1,
#  'Q63HR2': 91,
#  'A1A5C7': 12,
#  'O00214': 119,
#  'P12644': 98,
#  'P61421': 87,
#  'Q5T749': 70,
#  'Q6UY11': 28,
#  'Q86VP1': 63,
#  'Q8IXJ6': 72,
#  'Q9BVC3': 21,
#  'Q9Y5B6': 51,
#  'A1A5D9': 1,
#  'A1DRY3': 2,
#  'P36873': 594,
#  'A1E959': 4,
#  'Q14192': 112,
#  'Q9Y2I1': 49,
#  'A1IGU5': 2,
#  'Q9NQY0': 27,
#  'A1KXE4': 8,
#  'Q8IVT5': 446,
#  'Q9BYX4': 54,
#  'Q9H6Z9': 1259,
#  'A1KZ92': 5,
#  'Q13618': 1230,
#  'Q1MSJ5': 49,
#  'Q92882': 29,
#  'Q96T49': 20,
#  'A1L020': 12,
#  'P10636': 609,
#  'P11940': 344,
#  'Q13283': 518,
#  'Q99626': 22,
#  'Q9BS26': 101,
#  'A1L0T0': 57,
#  'O14829': 51,
#  'O15016': 198,
#  'O75170': 70,
#  'O95235': 991,
#  'O95696': 311,
#  'P07550': 225,
#  'P11441': 296,
#  'P18031': 176,
#  'P34972': 84,
#  'P52732': 181,
#  'P56180': 97,
#  'P83436': 25,
#  'Q13144': 53,
#  'Q13418': 263,
#  'Q15646': 122,
#  'Q5VZL5': 59,
#  'Q68CZ1': 169,
#  'Q6YHU6': 37,
#  'Q8N201': 79,
#  'Q92696': 26,
#  'Q96BD8': 41,
#  'Q96CB8': 43,
#  'Q96GD4': 574,
#  'Q96JQ5': 28,
#  'Q96QU8': 38,
#  'Q96T76': 222,
#  'Q9BZF3': 48,
#  'Q9C0E2': 52,
#  'Q9H4L5': 45,
#  'Q9HCG7': 11,
#  'Q9NRD5': 69,
#  'Q9P296': 56,
#  'Q9UBB6': 49,
#  'Q9UPN7': 95,
#  'A1L157': 12,
#  'O60462': 23,
#  'O75915': 55,
#  'P01189': 12,
#  'P05556': 167,
#  'P23229': 47,
#  'Q00765': 86,
#  'Q13683': 28,
#  'Q92544': 40,
#  'A1L167': 1,
#  'A1L170': 13,
#  'P53350': 336,
#  'Q13627': 387,
#  'Q15059': 200,
#  'Q8N5F7': 74,
#  'Q96CW1': 246,
#  'Q96HR8': 78,
#  'Q9NYY3': 46,
#  'Q9UKX3': 31,
#  'A1L188': 51,
#  'O14561': 43,
#  'O75891': 93,
#  'O95900': 60,
#  'P05141': 289,
#  'P07437': 397,
#  'P09651': 601,
#  'P21964': 48,
#  'P22626': 268,
#  'P42356': 93,
#  'P63261': 209,
#  'P68363': 260,
#  'P82673': 125,
#  'Q02878': 298,
#  'Q14257': 173,
#  'Q53S33': 28,
#  'Q5T9A4': 158,
#  'Q5TEU4': 51,
#  'Q6DKK2': 37,
#  'Q6P161': 21,
#  'Q7Z3D6': 10,
#  'Q8N8N7': 12,
#  ...}

# %%
degrees.items()
# Out:
# dict_items([('A0A024QYV7', 13), ('B4DJ51', 224), ('O60216', 258), ('P0CG48', 8494), ('P16455', 82), ('P35558', 86), ('P40337', 512), ('P51858', 213), ('P63104', 871), ('Q00653', 190), ('Q15004', 815), ('Q15843', 342), ('Q99558', 224), ('Q9Y6K9', 451), ('A0A024QZR3', 1), ('Q5S007', 2109), ('A0A024QZY1', 1), ('A0A024R087', 4), ('P61956', 1332), ('Q15014', 100), ('Q9UBU8', 97), ('A0A024R1A3', 1), ('A0A024R3C9', 3), ('P53355', 142), ('Q14847', 79), ('Q9NPD8', 28), ('A0A024R5U4', 119), ('O00217', 59), ('O14548', 15), ('O14925', 43), ('O14949', 48), ('O43169', 34), ('O43615', 72), ('O43676', 30), ('O43678', 38), ('O43819', 62), ('O43920', 68), ('O60488', 65), ('O75208', 225), ('O75251', 112), ('O75306', 106), ('O75380', 102), ('O75438', 18), ('O75439', 94), ('O75489', 247), ('O75947', 97), ('O95168', 41), ('O95182', 41), ('O95202', 54), ('O95299', 65), ('O95563', 19), ('P00387', 66), ('P01308', 471), ('P09669', 42), ('P10176', 5), ('P11047', 40), ('P12074', 22), ('P12236', 223), ('P14406', 39), ('P14735', 78), ('P14927', 44), ('P15954', 6), ('P18859', 57), ('P19404', 47), ('P20674', 68), ('P22695', 114), ('P22830', 56), ('P23786', 27), ('P24539', 109), ('P28288', 126), ('P28331', 113), ('P33121', 18), ('P36542', 167), ('P47985', 50), ('P48047', 144), ('P49821', 66), ('P51970', 81), ('P52789', 56), ('P53007', 185), ('P53701', 62), ('P53985', 98), ('P56381', 38), ('P56385', 43), ('P56556', 64), ('P60602', 7), ('Q00325', 207), ('Q07021', 361), ('Q07812', 99), ('Q10713', 88), ('Q13011', 215), ('Q13085', 122), ('Q13232', 42), ('Q13423', 44), ('Q15286', 50), ('Q16718', 77), ('Q16795', 124), ('Q16891', 167), ('Q3ZCQ8', 191), ('Q5JRX3', 39), ('Q5RI15', 21), ('Q6IAN0', 34), ('Q6P4A7', 39), ('Q6UXV4', 59), ('Q7L0Y3', 87), ('Q86SX6', 28), ('Q86Y39', 53), ('Q8N183', 20), ('Q8NI60', 76), ('Q8TC12', 42), ('Q8WWC4', 112), ('Q8WWV3', 20), ('Q969Z0', 54), ('Q96BW9', 36), ('Q96IX5', 64), ('Q96RQ3', 60), ('Q9BPW8', 97), ('Q9BRT2', 29), ('Q9BU61', 40), ('Q9BUB7', 32), ('Q9BVV7', 33), ('Q9H078', 91), ('Q9H4A6', 52), ('Q9H7Z7', 26), ('Q9H845', 96), ('Q9H9B4', 220), ('Q9NQE9', 10), ('Q9NRV9', 8), ('Q9NVI7', 321), ('Q9NX63', 108), ('Q9NZJ7', 34), ('Q9P032', 74), ('Q9P0J0', 92), ('Q9UDW1', 27), ('Q9UI09', 70), ('Q9UJZ1', 118), ('Q9Y2R0', 58), ('Q9Y2S7', 110), ('Q9Y3D6', 22), ('Q9Y3D7', 33), ('Q9Y4W6', 108), ('Q9Y512', 55), ('Q9Y5J9', 28), ('Q9Y697', 51), ('Q9Y6C9', 123), ('Q9Y6H1', 163), ('Q9Y6M9', 32), ('A0A024R687', 1), ('A0A024R6D8', 1), ('A0A024R718', 1), ('A0A024R7T3', 1), ('A0A024R7V6', 1), ('Q8TB24', 502), ('A0A024R821', 1), ('O75807', 204), ('A0A024R8A7', 1), ('A0A024R8E4', 1), ('A0A024R8U5', 1), ('A0A024R8W0', 1), ('A0A024R9F6', 4), ('Q7Z406', 89), ('Q96JM7', 36), ('Q96JN0', 74), ('Q9H9G7', 86), ('A0A024RA58', 1), ('A0A024RAE1', 1), ('A0A024RAZ7', 2), ('P67809', 493), ('A0A024RB16', 1), ('A0A024RBF6', 1), ('A0A024RC46', 2), ('P03372', 2211), ('Q92731', 2440), ('A0A024RCN6', 1), ('A0A024RCN7', 1), ('P13569', 1106), ('A0A024RDJ1', 1), ('A0A024RDV9', 1), ('A0A024RDY0', 1), ('A0A059RUZ1', 48), ('O43663', 892), ('O60885', 1332), ('O94972', 364), ('O95831', 373), ('P00533', 1356), ('P01106', 1965), ('P02751', 735), ('P11234', 62), ('P18433', 64), ('P21796', 295), ('P24941', 654), ('P27105', 141), ('P35232', 911), ('P35610', 187), ('P49116', 1350), ('P61586', 244), ('P78317', 1282), ('P83105', 185), ('Q13263', 1081), ('Q13794', 172), ('Q14197', 268), ('Q14999', 775), ('Q15029', 1352), ('Q16659', 309), ('Q16849', 68), ('Q5BJD5', 130), ('Q5JTJ3', 15), ('Q69YN4', 2754), ('Q6NUN9', 286), ('Q6UX01', 941), ('Q86VM9', 805), ('Q8IXH7', 48), ('Q96CS3', 276), ('Q96TA2', 76), ('Q9BVJ7', 85), ('Q9BXW9', 712), ('Q9H4D1', 326), ('Q9HCE5', 345), ('Q9NZ94', 29), ('Q9NZC7', 467), ('Q9P0S2', 9), ('U5YWV7', 29), ('A0A075B6P5', 1), ('P17813', 210), ('A0A075B6P9', 2), ('P27695', 999), ('P31943', 1165), ('A0A075B6R9', 1), ('Q9C0B5', 492), ('A0A075B6S6', 1), ('Q16526', 202), ('A0A075B759', 1), ('P0DN37', 20), ('A0A087WT10', 1), ('A0A087WWS6', 7), ('O94842', 77), ('P01562', 19), ...

# %%
degrees=dict(G.degree())
order=sorted(degrees.items(),key=lambda t:t[1])
x,y=zip(*order)
plt.plot(x,y)
plt.show()

# %%
from collections import Counter
degree_sequence = [G.degree(n) for n in G.nodes]
degree_counts = Counter(degree_sequence)
plt.xlabel("Degree", fontsize=20)
plt.ylabel("Frequency", fontsize=20)
plot_x = list(set(degree_sequence))
plot_y = [degree_counts.get(x,0) for x in plot_x]
plt.bar(plot_x, plot_y)
# Out:
# <BarContainer object of 529 artists>

# %%
import math
def plot_degree_dist(G):
    
    degrees = G.degree()
    degrees = dict(degrees)
    values = sorted(set(degrees.values()))
   
    histo = [list(degrees.values()).count(x) for x in values]
    P_k = [x / G.order() for x in histo]
   
    
    plt.figure()
    plt.bar(values, P_k)
    plt.xlabel("k",fontsize=20)
    plt.ylabel("p(k)", fontsize=20)
    plt.title("Degree Distribution", fontsize=20)
    
    plt.show()
    plt.figure()
    plt.loglog(values, P_k, "bo")
    plt.xlabel("k", fontsize=20)
    plt.ylabel("log p(k)", fontsize=20)
    plt.show()

# %%
plot_degree_dist(G)

# %%
import math
def plot_degree_dist(G):
    
    degrees = G.degree()
    degrees = dict(degrees)
    values = sorted(set(degrees.values()))
   
    histo = [list(degrees.values()).count(x) for x in values]
    P_k = [x / G.order() for x in histo]
   
    
    plt.figure()
    plt.bar(values, P_k)
    plt.xlabel("k",fontsize=20)
    plt.ylabel("p(k)", fontsize=20)
    plt.title("Degree Distribution", fontsize=20)
    
    plt.show()
    plt.figure()
    plt.loglog(values, P_k, "bo-")
    plt.xlabel("k", fontsize=20)
    plt.ylabel("log p(k)", fontsize=20)
    plt.show()

# %%
plot_degree_dist(G)

# %%
order
# Out:
# [('A0A024QZR3', 1),
#  ('A0A024QZY1', 1),
#  ('A0A024R1A3', 1),
#  ('A0A024R687', 1),
#  ('A0A024R6D8', 1),
#  ('A0A024R718', 1),
#  ('A0A024R7T3', 1),
#  ('A0A024R7V6', 1),
#  ('A0A024R821', 1),
#  ('A0A024R8A7', 1),
#  ('A0A024R8E4', 1),
#  ('A0A024R8U5', 1),
#  ('A0A024R8W0', 1),
#  ('A0A024RA58', 1),
#  ('A0A024RAE1', 1),
#  ('A0A024RB16', 1),
#  ('A0A024RBF6', 1),
#  ('A0A024RCN6', 1),
#  ('A0A024RCN7', 1),
#  ('A0A024RDJ1', 1),
#  ('A0A024RDV9', 1),
#  ('A0A024RDY0', 1),
#  ('A0A075B6P5', 1),
#  ('A0A075B6R9', 1),
#  ('A0A075B6S6', 1),
#  ('A0A075B759', 1),
#  ('A0A087WT10', 1),
#  ('A0A087X1V8', 1),
#  ('A0A096LP49', 1),
#  ('A0A096LPI6', 1),
#  ('A0A0A6YYB9', 1),
#  ('A0A0A6YYG8', 1),
#  ('A0A0A6YYH1', 1),
#  ('A0A0A6YYL4', 1),
#  ('A0A0K0K1K4', 1),
#  ('A0A0K0K1K7', 1),
#  ('A0A0M3HEQ9', 1),
#  ('A0A0S2Z4R1', 1),
#  ('A0A0U1RRH7', 1),
#  ('A0A0X9T7T4', 1),
#  ('A0A109NGN6', 1),
#  ('A0A140VJF4', 1),
#  ('A0A140VJK1', 1),
#  ('A0A140VJL3', 1),
#  ('A0A140VJP2', 1),
#  ('A0A140VJR2', 1),
#  ('A0A140VJS0', 1),
#  ('A0A140VJT0', 1),
#  ('A0A140VJT2', 1),
#  ('A0A140VJT8', 1),
#  ('A0A140VJW5', 1),
#  ('A0A140VJX1', 1),
#  ('A0A140VJY2', 1),
#  ('A0A140VJZ1', 1),
#  ('A0A140VJZ4', 1),
#  ('A0A140VK27', 1),
#  ('A0A140VK41', 1),
#  ('A0A140VK56', 1),
#  ('A0A140VK69', 1),
#  ('A0A140VK70', 1),
#  ('A0A140VKA6', 1),
#  ('A0A140VKE7', 1),
#  ('A0A140VKF1', 1),
#  ('A0A183YE00', 1),
#  ('A0A1U9X7U3', 1),
#  ('A0A1U9X8P6', 1),
#  ('A0A286YEY3', 1),
#  ('A0A2R8Y422', 1),
#  ('A0M8Q9', 1),
#  ('A0PJ86', 1),
#  ('A0PJY2', 1),
#  ('A1A5B4', 1),
#  ('A1A5D9', 1),
#  ('A1L167', 1),
#  ('A1L3X4', 1),
#  ('A1L453', 1),
#  ('A1L4K1', 1),
#  ('A2A2V5', 1),
#  ('A2A368', 1),
#  ('A2A3B6', 1),
#  ('A2A6V3', 1),
#  ('A2AJT9', 1),
#  ('A2CJ06', 1),
#  ('A2IDD5', 1),
#  ('A2J422', 1),
#  ('A2NJV5', 1),
#  ('A2RUQ5', 1),
#  ('A2RUR9', 1),
#  ('A2RUT3', 1),
#  ('A2VEC9', 1),
#  ('A3KPC7', 1),
#  ('A4D198', 1),
#  ('A4D1I1', 1),
#  ('A4D1J9', 1),
#  ('A4D1Z4', 1),
#  ('A4D256', 1),
#  ('A4D2D6', 1),
#  ('A4QPB2', 1),
#  ('A4QPH2', 1),
#  ('A5D6W6', 1),
#  ('A5D8W1', 1),
#  ('A5PLL1', 1),
#  ('A5PLN7', 1),
#  ('A6NCJ1', 1),
#  ('A6NCK2', 1),
#  ('A6NCN2', 1),
#  ('A6NCQ9', 1),
#  ('A6NCW0', 1),
#  ('A6ND48', 1),
#  ('A6NDI0', 1),
#  ('A6NDR6', 1),
#  ('A6NDV4', 1),
#  ('A6NE09', 1),
#  ('A6NEC2', 1),
#  ('A6NEE1', 1),
#  ('A6NEK1', 1),
#  ('A6NEL3', 1),
#  ('A6NER0', 1),
#  ('A6NEW6', 1),
#  ('A6NFA0', 1),
#  ('A6NFN9', 1),
#  ('A6NFT4', 1),
#  ('A6NGH7', 1),
#  ('A6NGQ2', 1),
#  ('A6NH52', 1),
#  ('A6NHN0', 1),
#  ('A6NHS7', 1),
#  ('A6NHY2', 1),
#  ('A6NI72', 1),
#  ('A6NI73', 1),
#  ('A6NIE6', 1),
#  ('A6NIJ9', 1),
#  ('A6NJ69', 1),
#  ('A6NJT0', 1),
#  ('A6NK44', 1),
#  ('A6NK58', 1),
#  ('A6NK97', 1),
#  ('A6NKF2', 1),
#  ('A6NKN8', 1),
#  ('A6NKQ9', 1),
#  ('A6NL08', 1),
#  ('A6NLC5', 1),
#  ('A6NLF2', 1),
#  ('A6NLI5', 1),
#  ('A6NLR5', 1),
#  ('A6NM11', 1),
#  ('A6NMB1', 1),
#  ('A6NMB9', 1),
#  ('A6NMD2', 1),
#  ('A6NMK8', 1),
#  ('A6NML5', 1),
#  ('A6NMS7', 1),
#  ('A6NP11', 1),
#  ('A6PVY3', 1),
#  ('A6QKW0', 1),
#  ('A7MBM2', 1),
#  ('A7MD48', 1),
#  ('A8JZZ8', 1),
#  ('A8K008', 1),
#  ('A8K132', 1),
#  ('A8K146', 1),
#  ('A8K1X2', 1),
#  ('A8K2R3', 1),
#  ('A8K2S1', 1),
#  ('A8K394', 1),
#  ('A8K3C3', 1),
#  ('A8K3K1', 1),
#  ('A8K3S1', 1),
#  ('A8K3W4', 1),
#  ('A8K3Y8', 1),
#  ('A8K492', 1),
#  ('A8K4A8', 1),
#  ('A8K4B4', 1),
#  ('A8K4M5', 1),
#  ('A8K4T8', 1),
#  ('A8K4Z4', 1),
#  ('A8K566', 1),
#  ('A8K588', 1),
#  ('A8K5B0', 1),
#  ('A8K5B6', 1),
#  ('A8K5C4', 1),
#  ('A8K5K0', 1),
#  ('A8K5M4', 1),
#  ('A8K5N5', 1),
#  ('A8K5Q1', 1),
#  ('A8K5T7', 1),
#  ('A8K5U9', 1),
#  ('A8K5Y2', 1),
#  ('A8K5Y7', 1),
#  ('A8K644', 1),
#  ('A8K690', 1),
#  ('A8K6I4', 1),
#  ('A8K6K7', 1),
#  ('A8K6V7', 1),
#  ('A8K781', 1),
#  ('A8K7I4', 1),
#  ('A8K7N0', 1),
#  ('A8K8A6', 1),
#  ('A8K8D9', 1),
#  ('A8K8K1', 1),
#  ('A8K8U7', 1),
#  ('A8K962', 1),
#  ('A8K984', 1),
#  ('A8K9A4', 1),
#  ('A8K9A5', 1),
#  ('A8K9E1', 1),
#  ('A8K9K4', 1),
#  ('A8K9K6', 1),
#  ('A8K9U0', 1),
#  ('A8KA74', 1),
#  ('A8KAG1', 1),
#  ('A8KAH1', 1),
#  ('A8KAP3', 1),
#  ('A8MPX8', 1),
#  ('A8MTA8', 1),
#  ('A8MTY7', 1),
#  ('A8MU46', 1),
#  ('A8MUK1', 1),
#  ('A8MUP2', 1),
#  ('A8MUX0', 1),
#  ('A8MUZ8', 1),
#  ('A8MV24', 1),
#  ('A8MVJ9', 1),
#  ('A8MWL7', 1),
#  ('A8MXD5', 1),
#  ('A8MXJ8', 1),
#  ('A8MXQ7', 1),
#  ('A8MXV6', 1),
#  ('A8MXY4', 1),
#  ('A8MXZ3', 1),
#  ('A8MYV0', 1),
#  ('A8MZ36', 1),
#  ('A8MZG2', 1),
#  ('A9CP04', 1),
#  ('B0AZQ4', 1),
#  ('B0AZT6', 1),
#  ('B0AZU3', 1),
#  ('B0UXC6', 1),
#  ('B1AHC3', 1),
#  ('B1ALB5', 1),
#  ('B1AME3', 1),
#  ('B1AMU2', 1),
#  ('B1AN94', 1),
#  ('B1APH4', 1),
#  ('B1Q2B0', 1),
#  ('B2CQT6', 1),
#  ('B2R4C0', 1),
#  ('B2R4C1', 1),
#  ('B2R4D8', 1),
#  ('B2R4V2', 1),
#  ('B2R5I8', 1),
#  ('B2R5M9', 1),
#  ('B2R602', 1),
#  ('B2R623', 1),
#  ('B2R643', 1),
#  ('B2R657', 1),
#  ('B2R665', 1),
#  ('B2R673', 1),
#  ('B2R679', 1),
#  ('B2R6D4', 1),
#  ('B2R6D7', 1),
#  ('B2R6F5', 1),
#  ('B2R6J2', 1),
#  ('B2R6K0', 1),
#  ('B2R6K1', 1),
#  ('B2R6K4', 1),
#  ('B2R6S4', 1),
#  ('B2R713', 1),
#  ('B2R739', 1),
#  ('B2R7C2', 1),
#  ('B2R7E8', 1),
#  ('B2R7J8', 1),
#  ('B2R7P8', 1),
#  ('B2R841', 1),
#  ('B2R8N1', 1),
#  ('B2R921', 1),
#  ('B2R935', 1),
#  ('B2R960', 1),
#  ('B2R983', 1),
#  ('B2R9K8', 1),
#  ('B2R9X3', 1),
#  ('B2RA03', 1),
#  ('B2RAD8', 1),
#  ('B2RAH7', 1),
#  ('B2RAM6', 1),
#  ('B2RAR2', 1),
#  ('B2RAU5', 1),
#  ('B2RAU8', 1),
#  ('B2RAX6', 1),
#  ('B2RB52', 1),
#  ('B2RBB2', 1),
#  ('B2RBI0', 1),
#  ('B2RBP3', 1),
#  ('B2RBS8', 1),
#  ('B2RCD8', 1),
#  ('B2RCF3', 1),
#  ('B2RCI8', 1),
#  ('B2RCM6', 1),
#  ('B2RCT6', 1),
#  ('B2RCW4', 1),
#  ('B2RD27', 1),
#  ('B2RD36', 1),
#  ('B2RD79', 1),
#  ('B2RDD7', 1),
#  ('B2RDF5', 1),
#  ('B2RDI7', 1),
#  ('B2RDN9', 1),
#  ('B2RDP6', 1),
#  ('B2RDQ3', 1),
#  ('B2RDY9', 1),
#  ('B2RWN9', 1),
#  ('B3KM34', 1),
#  ('B3KM47', 1),
#  ('B3KM48', 1),
#  ('B3KM58', 1),
#  ('B3KME2', 1),
#  ('B3KML1', 1),
#  ('B3KMQ7', 1),
#  ('B3KMR5', 1),
#  ('B3KN28', 1),
#  ('B3KN52', 1),
#  ('B3KNB4', 1),
#  ('B3KNK9', 1),
#  ('B3KNN7', 1),
#  ('B3KNS7', 1),
#  ('B3KP95', 1),
#  ('B3KPC1', 1),
#  ('B3KQ33', 1),
#  ('B3KQJ0', 1),
#  ('B3KQQ3', 1),
#  ('B3KQT9', 1),
#  ('B3KRA9', 1),
#  ('B3KRM2', 1),
#  ('B3KRP9', 1),
#  ('B3KRQ2', 1),
#  ('B3KRS1', 1),
#  ('B3KS06', 1),
#  ('B3KSS1', 1),
#  ('B3KSX3', 1),
#  ('B3KSZ4', 1),
#  ('B3KT18', 1),
#  ('B3KT93', 1),
#  ('B3KTJ9', 1),
#  ('B3KTT5', 1),
#  ('B3KTV0', 1),
#  ('B3KU03', 1),
#  ('B3KU91', 1),
#  ('B3KUJ0', 1),
#  ('B3KUP4', 1),
#  ('B3KUZ7', 1),
#  ('B3KVX6', 1),
#  ('B3KW06', 1),
#  ('B3KW14', 1),
#  ('B3KW34', 1),
#  ('B3KW79', 1),
#  ('B3KWI4', 1),
#  ('B3KWV6', 1),
#  ('B3KWX7', 1),
#  ('B3KX11', 1),
#  ('B3KX42', 1),
#  ('B3KX72', 1),
#  ('B3KXG1', 1),
#  ('B3KXU8', 1),
#  ('B3KXW5', 1),
#  ('B3KY54', 1),
#  ('B3KY97', 1),
#  ('B4DDL9', 1),
#  ('B4DDU6', 1),
#  ('B4DE76', 1),
#  ('B4DE78', 1),
#  ('B4DEF8', 1),
#  ('B4DF61', 1),
#  ('B4DG76', 1),
#  ('B4DGN8', 1),
#  ('B4DGR3', 1),
#  ('B4DH39', 1),
#  ('B4DH59', 1),
#  ('B4DHC4', 1),
#  ('B4DHQ3', 1),
#  ('B4DIR9', 1),
#  ('B4DJ30', 1),
#  ('B4DJ38', 1),
#  ('B4DJQ5', 1),
#  ('B4DJV9', 1),
#  ('B4DJY2', 1),
#  ('B4DKM0', 1),
#  ('B4DKR1', 1),
#  ('B4DKS0', 1),
#  ('B4DLD4', 1),
#  ('B4DLG2', 1),
#  ('B4DLV7', 1),
#  ('B4DM97', 1),
#  ('B4DMA8', 1),
#  ('B4DMH3', 1),
#  ('B4DMY3', 1),
#  ('B4DMZ9', 1),
#  ('B4DN52', 1),
#  ('B4DN72', 1),
#  ('B4DN87', 1),
#  ('B4DNA3', 1),
#  ('B4DNC0', 1),
#  ('B4DNL5', 1),
#  ('B4DNQ8', 1),
#  ('B4DNS4', 1),
#  ('B4DP54', 1),
#  ('B4DP77', 1),
#  ('B4DPS6', 1),
#  ('B4DPZ4', 1),
#  ('B4DQ50', 1),
#  ('B4DQ88', 1),
#  ('B4DQE5', 1),
#  ('B4DQI7', 1),
#  ('B4DQN9', 1),
#  ('B4DQQ1', 1),
#  ('B4DQY1', 1),
#  ('B4DQY2', 1),
#  ('B4DR67', 1),
#  ('B4DRD7', 1),
#  ('B4DRI6', 1),
#  ('B4DRL5', 1),
#  ('B4DRS6', 1),
#  ('B4DS05', 1),
#  ('B4DS77', 1),
#  ('B4DSH1', 1),
#  ('B4DSQ5', 1),
#  ('B4DSR6', 1),
#  ('B4DTA2', 1),
#  ('B4DTP6', 1),
#  ('B4DU42', 1),
#  ('B4DUJ2', 1),
#  ('B4DUP2', 1),
#  ('B4DUQ1', 1),
#  ('B4DV73', 1),
#  ('B4DVH1', 1),
#  ('B4DW97', 1),
#  ('B4DWA6', 1),
#  ('B4DWB5', 1),
#  ('B4DWV9', 1),
#  ('B4DWX3', 1),
#  ('B4DXL2', 1),
#  ('B4DXR9', 1),
#  ('B4DYM8', 1),
#  ('B4DZ07', 1),
#  ('B4DZC0', 1),
#  ('B4DZF2', 1),
#  ('B4DZG6', 1),
#  ('B4DZH6', 1),
#  ('B4DZW9', 1),
#  ('B4DZZ1', 1),
#  ('B4E022', 1),
#  ('B4E083', 1),
#  ('B4E0L0', 1),
#  ('B4E136', 1),
#  ('B4E1D9', 1),
#  ('B4E1Q7', 1),
#  ('B4E1R7', 1),
#  ('B4E1Z4', 1),
#  ('B4E229', 1),
#  ('B4E266', 1),
#  ('B4E290', 1),
#  ('B4E2L0', 1),
#  ('B4E312', 1),
#  ('B5ME56', 1),
#  ('B7Z1J9', 1),
#  ('B7Z1M9', 1),
#  ('B7Z1N3', 1),
#  ('B7Z269', 1),
#  ('B7Z2B5', 1),
#  ('B7Z2F4', 1),
#  ('B7Z2P6', 1),
#  ('B7Z2W3', 1),
#  ('B7Z3H9', 1),
#  ('B7Z3K3', 1),
#  ('B7Z3K9', 1),
#  ('B7Z3V1', 1),
#  ('B7Z4L7', 1),
#  ('B7Z4N6', 1),
#  ('B7Z563', 1),
#  ('B7Z6D1', 1),
#  ('B7Z6F7', 1),
#  ('B7Z6H4', 1),
#  ('B7Z6K7', 1),
#  ('B7Z6M0', 1),
#  ('B7Z6Q5', 1),
#  ('B7Z7T5', 1),
#  ('B7Z7U6', 1),
#  ('B7Z8E4', 1),
#  ('B7Z8Q2', 1),
#  ('B7Z8W3', 1),
#  ('B7Z8Y3', 1),
#  ('B7Z9C4', 1),
#  ('B7Z9C6', 1),
#  ('B7Z9L0', 1),
#  ('B7ZAC7', 1),
#  ('B7ZAF0', 1),
#  ('B7ZB44', 1),
#  ('B7ZBS5', 1),
#  ('B7ZLF8', 1),
#  ('B7ZW15', 1),
#  ('P0DOY3', 1),
#  ('B9EJG8', 1),
#  ('C4B4C6', 1),
#  ('C4P0D4', 1),
#  ('C9IYR8', 1),
#  ('C9J2D9', 1),
#  ('C9J3V5', 1),
#  ('C9JBB2', 1),
#  ('C9JBW2', 1),
#  ('C9JCN9', 1),
#  ('C9JF75', 1),
#  ('C9JHA6', 1),
#  ('C9JI98', 1),
#  ('C9JIN9', 1),
#  ('C9JJ98', 1),
#  ('C9JL84', 1),
#  ('C9JPN9', 1),
#  ('D0EYG5', 1),
#  ('D3DPS3', 1),
#  ('D3DQZ6', 1),
#  ('D3DS95', 1),
#  ('D3DSW1', 1),
#  ('D3DT21', 1),
#  ('D3DU01', 1),
#  ('D3DWK4', 1),
#  ('D6RGX4', 1),
#  ('D6RIA3', 1),
#  ('E5KMT5', 1),
#  ('E5KN59', 1),
#  ('E5KR06', 1),
#  ('E5KT65', 1),
#  ('E7D7X9', 1),
#  ('E7EMQ9', 1),
#  ('E7EMX6', 1),
#  ('E7ENA2', 1),
#  ('E7EW26', 1),
#  ('E9PG94', 1),
#  ('E9PJ23', 1),
#  ('E9PLN8', 1),
#  ('E9PQ53', 1),
#  ('F1D8P6', 1),
#  ('F2Z333', 1),
#  ('F2Z384', 1),
#  ('F2Z3L0', 1),
#  ('F5CTF3', 1),
#  ('F5GX27', 1),
#  ('F5GZ44', 1),
#  ('H7C030', 1),
#  ('F5H122', 1),
#  ('F5H1Q3', 1),
#  ('F5H254', 1),
#  ('F5H2Q5', 1),
#  ('F5H423', 1),
#  ('F5H4T9', 1),
#  ('F5H5H7', 1),
#  ('F5H5S2', 1),
#  ('F5H827', 1),
#  ('F5H8M2', 1),
#  ('F6S8J2', 1),
#  ('F6WH68', 1),
#  ('F8VRH9', 1),
#  ('F8VSA3', 1),
#  ('F8VZ54', 1),
#  ('F8VZD8', 1),
#  ('F8VZG7', 1),
#  ('F8W6L4', 1),
#  ('F8W786', 1),
#  ('F8W8X7', 1),
#  ('F8WC28', 1),
#  ('G3V0F1', 1),
#  ('G3V0H6', 1),
#  ('G3V4V3', 1),
#  ('G9K388', 1),
#  ('H0Y8B7', 1),
#  ('H0YAA0', 1),
#  ('H0YJ32', 1),
#  ('H0YL14', 1),
#  ('H0YLM1', 1),
#  ('H0YMZ9', 1),
#  ('H3BPM6', 1),
#  ('H3BQR6', 1),
#  ('H3BRN7', 1),
#  ('H7BXD9', 1),
#  ('H7BZN0', 1),
#  ('H7C417', 1),
#  ('H9KVA4', 1),
#  ('I1SRC5', 1),
#  ('I1YAP6', 1),
#  ('I3L0A0', 1),
#  ('I3L0A4', 1),
#  ('I3L142', 1),
#  ('I3L1D8', 1),
#  ('I3L2R1', 1),
#  ('I3L420', 1),
#  ('I3L4Q8', 1),
#  ('I6L899', 1),
#  ('I6L8F1', 1),
#  ('I7GY12', 1),
#  ('J3KNK4', 1),
#  ('J3KNL3', 1),
#  ('J3KQ23', 1),
#  ('J3KQ88', 1),
#  ('J3KR86', 1),
#  ('J3QQQ9', 1),
#  ('K7EKI2', 1),
#  ('K7EMB3', 1),
#  ('K7EMG9', 1),
#  ('K7ENZ8', 1),
#  ('K7ES03', 1),
#  ('L0R6D6', 1),
#  ('L7N2F9', 1),
#  ('M0R2C6', 1),
#  ('M0R2J8', 1),
#  ('O00144', 1),
#  ('Q5GH72', 1),
#  ('Q8WXS8', 1),
#  ('O00254', 1),
#  ('O00292', 1),
#  ('O00321', 1),
#  ('O75897', 1),
#  ('Q9UPU3', 1),
#  ('P17031', 1),
#  ('P46094', 1),
#  ('P56715', 1),
#  ('Q6IEZ7', 1),
#  ('Q8IUK5', 1),
#  ('Q8IUY3', 1),
#  ('Q8NH02', 1),
#  ('Q8TDI7', 1),
#  ('Q9BWV2', 1),
#  ('Q9H5P4', 1),
#  ('Q9UQ52', 1),
#  ('O00591', 1),
#  ('Q8IZF2', 1),
#  ('O00748', 1),
#  ('Q9ULI1', 1),
#  ('O14529', 1),
#  ('Q8NA57', 1),
#  ('O14569', 1),
#  ('P34982', 1),
#  ('Q5TFG8', 1),
#  ('Q5VTH9', 1),
#  ('Q7Z745', 1),
#  ('Q8NGM1', 1),
#  ('Q8WWB5', 1),
#  ('Q9H4I0', 1),
#  ('O14598', 1),
#  ('O14638', 1),
#  ('Q5R2U3', 1),
#  ('Q08E93', 1),
#  ('O14718', 1),
#  ('Q9Y2B2', 1),
#  ('O14791', 1),
#  ('Q96NZ8', 1),
#  ('Q6ZUT3', 1),
#  ('O14957', 1),
#  ('O14960', 1),
#  ('O75333', 1),
#  ('O94993', 1),
#  ('Q15319', 1),
#  ('Q68D06', 1),
#  ('O15072', 1),
#  ('O15130', 1),
#  ('Q9BYH1', 1),
#  ('O15178', 1),
#  ('Q9H2W2', 1),
#  ('O15209', 1),
#  ('O15244', 1),
#  ('O15245', 1),
#  ('Q9H3H1', 1),
#  ('Q8IYR0', 1),
#  ('Q15270', 1),
#  ('Q7Z4H1', 1),
#  ('Q969S6', 1),
#  ('O15451', 1),
#  ('O15466', 1),
#  ('O15467', 1),
#  ('O15499', 1),
#  ('O15522', 1),
#  ('Q6A1A2', 1),
#  ('O43155', 1),
#  ('O43174', 1),
#  ('Q96IS3', 1),
#  ('O43194', 1),
#  ('O43246', 1),
#  ('O43280', 1),
#  ('O43315', 1),
#  ('O43316', 1),
#  ('O43345', 1),
#  ('O43361', 1),
#  ('P57055', 1),
#  ('Q8IZS8', 1),
#  ('O43506', 1),
#  ('Q9BZE3', 1),
#  ('O43555', 1),
#  ('Q53ZZ1', 1),
#  ('Q76P68', 1),
#  ('Q8N4B4', 1),
#  ('O43677', 1),
#  ('Q9ULZ1', 1),
#  ('O43699', 1),
#  ('O43704', 1),
#  ('Q8TCW9', 1),
#  ('O43763', 1),
#  ('P58549', 1),
#  ('O43812', 1),
#  ('Q8N8X9', 1),
#  ('Q08ET2', 1),
#  ('Q14952', 1),
#  ('P47887', 1),
#  ('P49640', 1),
#  ('Q12870', 1),
#  ('Q549J4', 1),
#  ('Q9NZD4', 1),
#  ('O60225', 1),
#  ('Q5VWW1', 1),
#  ('Q7Z5L3', 1),
#  ('O60290', 1),
#  ('O60304', 1),
#  ('O60309', 1),
#  ('Q8NCR9', 1),
#  ('O60449', 1),
#  ('O60479', 1),
#  ('Q9BXJ7', 1),
#  ('O60535', 1),
#  ('O60542', 1),
#  ('Q9GZZ7', 1),
#  ('O60609', 1),
#  ('Q5T4W7', 1),
#  ('O60635', 1),
#  ('P29973', 1),
#  ('P78358', 1),
#  ('Q86YL1', 1),
#  ('Q8IYB4', 1),
#  ('O60747', 1),
#  ('O60748', 1),
#  ('O60755', 1),
#  ('O60756', 1),
#  ('O60760', 1),
#  ('UPI000013F4A0', 1),
#  ('O60810', 1),
#  ('O60811', 1),
#  ('Q9NWJ6', 1),
#  ('Q6ZNM6', 1),
#  ('O60931', 1),
#  ('O75019', 1),
#  ('Q6PI73', 1),
#  ('Q8IZ02', 1),
#  ('O75074', 1),
#  ('O75077', 1),
#  ('O75094', 1),
#  ('Q53HG7', 1),
#  ('O94769', 1),
#  ('Q5T0N1', 1),
#  ('O75311', 1),
#  ('Q96DD7', 1),
#  ('Q9H5W7', 1),
#  ('Q96S90', 1),
#  ('O75425', 1),
#  ('Q96JC4', 1),
#  ('O75452', 1),
#  ('O75459', 1),
#  ('Q15559', 1),
#  ('Q49A15', 1),
#  ('Q8N1K8', 1),
#  ('Q96KT1', 1),
#  ('O75602', 1),
#  ('O75603', 1),
#  ('O75631', 1),
#  ('O75841', 1),
#  ('O75677', 1),
#  ('O75747', 1),
#  ('O75795', 1),
#  ('Q0QEN7', 1),
#  ('Q1KLZ0', 1),
#  ('Q2I0Y7', 1),
#  ('Q2TSD0', 1),
#  ('Q562V5', 1),
#  ('Q59EY3', 1),
#  ('O75830', 1),
#  ('O75838', 1),
#  ('Q8N1V8', 1),
#  ('O75900', 1),
#  ('Q6ZS82', 1),
#  ('Q9H205', 1),
#  ('O76093', 1),
#  ('Q8WU08', 1),
#  ('O76099', 1),
#  ('O76100', 1),
#  ('Q6P5Q4', 1),
#  ('Q96PN6', 1),
#  ('O94778', 1),
#  ('P07510', 1),
#  ('Q8NGS5', 1),
#  ('O94892', 1),
#  ('Q96MU8', 1),
#  ('O94911', 1),
#  ('O94956', 1),
#  ('Q6UWN5', 1),
#  ('P0CB33', 1),
#  ('Q9NZW4', 1),
#  ('O95006', 1),
#  ('O95025', 1),
#  ('O95045', 1),
#  ('Q3KQV9', 1),
#  ('Q685J3', 1),
#  ('Q8TBM7', 1),
#  ('Q6NXP6', 1),
#  ('O95377', 1),
#  ('O95397', 1),
#  ('O95406', 1),
#  ('O95416', 1),
#  ('O95452', 1),
#  ('Q8N8Q8', 1),
#  ('Q9NS66', 1),
#  ('O95522', 1),
#  ('O95626', 1),
#  ('Q659F9', 1),
#  ('Q5TYW2', 1),
#  ('P48775', 1),
#  ('Q9NQ32', 1),
#  ('Q07507', 1),
#  ('O95727', 1),
#  ('O95750', 1),
#  ('P48664', 1),
#  ('P51814', 1),
#  ('P78411', 1),
#  ('Q0VD83', 1),
#  ('Q2NL67', 1),
#  ('Q53GD3', 1),
#  ('Q5JXM2', 1),
#  ('Q6EBC2', 1),
#  ('Q6UWV7', 1),
#  ('Q6UX52', 1),
#  ('Q6UX98', 1),
#  ('Q6UXD7', 1),
#  ('Q7RTP0', 1),
#  ('Q86VL8', 1),
#  ('Q8IYN6', 1),
#  ('Q8N3T1', 1),
#  ('Q8N812', 1),
#  ('Q8NBI2', 1),
#  ('Q8TC90', 1),
#  ('Q8WXF5', 1),
#  ('Q93033', 1),
#  ('Q96H72', 1),
#  ('Q96MZ0', 1),
#  ('Q96NR3', 1),
#  ('Q96RD6', 1),
#  ('Q9BYG0', 1),
#  ('Q9BZD2', 1),
#  ('Q9H3S4', 1),
#  ('Q9H3T3', 1),
#  ('Q9HC96', 1),
#  ('Q9UMR7', 1),
#  ('Q9UQ05', 1),
#  ('Q9Y6H6', 1),
#  ('Q9BX84', 1),
#  ('O95803', 1),
#  ('P07451', 1),
#  ('P29377', 1),
#  ('Q6UE05', 1),
#  ('Q7Z769', 1),
#  ('Q8NG75', 1),
#  ('Q8NGC4', 1),
#  ('Q8NGM9', 1),
#  ('Q8WUU8', 1),
#  ('Q96BF3', 1),
#  ('Q96KN4', 1),
#  ('Q96KX0', 1),
#  ('Q9BXJ2', 1),
#  ('Q9NZH7', 1),
#  ('O95847', 1),
#  ('O95867', 1),
#  ('O95876', 1),
#  ('O95954', 1),
#  ('O95965', 1),
#  ('O95971', 1),
#  ('Q5H9J7', 1),
#  ('Q8TBY0', 1),
#  ('O95998', 1),
#  ('P00439', 1),
#  ('P56750', 1),
#  ('P0CG32', 1),
#  ('P60411', 1),
#  ('Q14833', 1),
#  ('Q16099', 1),
#  ('Q3LI76', 1),
#  ('Q59EJ3', 1),
#  ('Q59G22', 1),
#  ('Q59GR8', 1),
#  ('Q5JUK9', 1),
#  ('Q5T1H1', 1),
#  ('Q5XG92', 1),
#  ('Q7Z3T1', 1),
#  ('Q86SP6', 1),
#  ('Q8N7B9', 1),
#  ('Q9NP60', 1),
#  ('Q9UGL9', 1),
#  ('Q92496', 1),
#  ('Q5VV43', 1),
#  ('Q6XYB7', 1),
#  ('Q6ZSX8', 1),
#  ('Q6ZUB1', 1),
#  ('Q8IUA7', 1),
#  ('Q96L53', 1),
#  ('Q96L96', 1),
#  ('Q9HCK3', 1),
#  ('Q9UIL4', 1),
#  ('Q6P6B7', 1),
#  ('P01286', 1),
#  ('P01303', 1),
#  ('P25929', 1),
#  ('Q5T0D9', 1),
#  ('Q9Y493', 1),
#  ('Q86W67', 1),
#  ('P01597', 1),
#  ('P01599', 1),
#  ('P01703', 1),
#  ('P01714', 1),
#  ('P01763', 1),
#  ('P01780', 1),
#  ('P28039', 1),
#  ('P35542', 1),
#  ('Q8NGV6', 1),
#  ('Q9UL92', 1),
#  ('P01906', 1),
#  ('P22914', 1),
#  ('P10266', 1),
#  ('Q8N139', 1),
#  ('Q92484', 1),
#  ('Q04118', 1),
#  ('Q5T442', 1),
#  ('Q68DD2', 1),
#  ('Q6ZMN7', 1),
#  ('Q8N5Q1', 1),
#  ('Q8NHC8', 1),
#  ('Q8NHM4', 1),
#  ('Q9Y259', 1),
#  ('Q8TE69', 1),
#  ('P02812', 1),
#  ('P02818', 1),
#  ('P11086', 1),
#  ('P17025', 1),
#  ('Q12837', 1),
#  ('Q6ZN28', 1),
#  ('Q75MW2', 1),
#  ('Q8N268', 1),
#  ('P03897', 1),
#  ('Q8N699', 1),
#  ('Q9BSY4', 1),
#  ('P04118', 1),
#  ('Q9NYZ4', 1),
#  ('Q13791', 1),
#  ('Q53EM5', 1),
#  ('Q5W0B7', 1),
#  ('P04433', 1),
#  ('Q9UEX5', 1),
#  ('Q14863', 1),
#  ('Q8N4K4', 1),
#  ('Q9Y5W5', 1),
#  ('Q6ZNH5', 1),
#  ('Q9Y5E6', 1),
#  ('P19113', 1),
#  ('Q2M385', 1),
#  ('Q587J7', 1),
#  ('Q6DHV5', 1),
#  ('Q8IXF0', 1),
#  ('Q8IXS0', 1),
#  ('Q8TC20', 1),
#  ('Q99581', 1),
#  ('Q9H095', 1),
#  ('Q9H2S5', 1),
#  ('Q9UFV9', 1),
#  ('P04732', 1),
#  ('Q5TA76', 1),
#  ('P04921', 1),
#  ('P05015', 1),
#  ('P0DN86', 1),
#  ('P0DTW1', 1),
#  ('P22749', 1),
#  ('P39900', 1),
#  ('P78383', 1),
#  ('Q0VGM3', 1),
#  ('Q13875', 1),
#  ('Q13939', 1),
#  ('Q15622', 1),
#  ('Q15726', 1),
#  ('Q3MIW9', 1),
#  ('Q460N3', 1),
#  ('Q4AE62', 1),
#  ('Q53FP2', 1),
#  ('Q53QW1', 1),
#  ('Q5BKX8', 1),
#  ('Q5TZF3', 1),
#  ('Q5W5X9', 1),
#  ('Q6GMR7', 1),
#  ('Q6IPW1', 1),
#  ('Q6P9H5', 1),
#  ('Q6UWN8', 1),
#  ('Q7L5A3', 1),
#  ...]

# %%
ll=len(order)
f=int(ll*0.05)

# %%
f
# Out:
# 910

# %%
bb=[]

# %%
for x in range (len(order)-f,len(order)):
    bb.append(order[x][0])

# %%
bb
# Out:
# ['Q06609',
#  'Q13885',
#  'P60900',
#  'P08195',
#  'Q13557',
#  'Q13363',
#  'Q5T9A4',
#  'Q9P2J5',
#  'Q8N0Z3',
#  'P29401',
#  'Q13042',
#  'O43707',
#  'P23497',
#  'O43290',
#  'P09661',
#  'P49792',
#  'P51398',
#  'O14579',
#  'P55084',
#  'P41218',
#  'P61077',
#  'O43172',
#  'P37173',
#  'P01112',
#  'Q9UKV5',
#  'P48730',
#  'P21675',
#  'Q99575',
#  'O43175',
#  'Q7Z434',
#  'Q7Z7A1',
#  'P19174',
#  'Q15388',
#  'P0C0S5',
#  'P41252',
#  'O95373',
#  'Q92878',
#  'Q92945',
#  'P62899',
#  'Q14694',
#  'Q14145',
#  'P41182',
#  'P52907',
#  'P22736',
#  'Q15637',
#  'O00264',
#  'P62244',
#  'P43699',
#  'P33991',
#  'Q96HS1',
#  'Q9UM54',
#  'P15923',
#  'Q5J8M3',
#  'Q9Y6H1',
#  'P42696',
#  'Q9BYG3',
#  'Q96SW2',
#  'Q96AP4',
#  'P11802',
#  'Q00059',
#  'O60832',
#  'P19387',
#  'P29692',
#  'P49840',
#  'P62714',
#  'Q92922',
#  'P10644',
#  'P61244',
#  'P62318',
#  'O60563',
#  'P35268',
#  'Q15139',
#  'Q9UER7',
#  'Q6W2J9',
#  'P35580',
#  'P51114',
#  'Q15797',
#  'Q14108',
#  'P46783',
#  'Q02750',
#  'Q15650',
#  'P83731',
#  'Q15050',
#  'P51610',
#  'Q8N5H7',
#  'Q92993',
#  'Q15366',
#  'Q13526',
#  'P62979',
#  'P36542',
#  'Q16891',
#  'Q9Y5B0',
#  'P05556',
#  'P35228',
#  'O95782',
#  'Q9Y5M8',
#  'Q8TAQ2',
#  'P10909',
#  'P62879',
#  'P04350',
#  'P51617',
#  'Q12931',
#  'P51668',
#  'P10276',
#  'Q68CZ1',
#  'P83916',
#  'Q13490',
#  'Q99729',
#  'O76071',
#  'P23528',
#  'Q8N3V7',
#  'P42766',
#  'P46087',
#  'Q9BWF3',
#  'P51587',
#  'P62316',
#  'O43684',
#  'P05771',
#  'Q01082',
#  'Q8IUH3',
#  'Q92598',
#  'O00743',
#  'Q04637',
#  'O95292',
#  'Q9NR12',
#  'P62306',
#  'O60739',
#  'P34947',
#  'Q13794',
#  'P11388',
#  'O43242',
#  'P00519',
#  'Q14257',
#  'O15164',
#  'P46734',
#  'P27797',
#  'Q99460',
#  'P62081',
#  'Q66GS9',
#  'P19474',
#  'P47756',
#  'P51148',
#  'Q13153',
#  'O75376',
#  'P52815',
#  'Q02539',
#  'P25786',
#  'Q14152',
#  'Q9C002',
#  'P41743',
#  'O96019',
#  'P16615',
#  'P62191',
#  'Q15428',
#  'P38159',
#  'P05387',
#  'P61353',
#  'P18031',
#  'Q15369',
#  'O15111',
#  'Q92499',
#  'Q9UNX3',
#  'Q9BZE4',
#  'Q16539',
#  'P06239',
#  'P23588',
#  'Q15691',
#  'P20226',
#  'Q9Y3U8',
#  'Q13315',
#  'Q13595',
#  'Q08945',
#  'P05362',
#  'P25963',
#  'Q9NS69',
#  'Q8NAX2',
#  'P07814',
#  'P78347',
#  'Q15020',
#  'Q9ULK4',
#  'Q14457',
#  'P43686',
#  'P62314',
#  'O43809',
#  'P27361',
#  'Q05639',
#  'O14654',
#  'P49674',
#  'P18206',
#  'P10412',
#  'P19388',
#  'Q16637',
#  'P52732',
#  'P49459',
#  'Q9Y3E0',
#  'O15372',
#  'P51151',
#  'P05023',
#  'Q8IXL6',
#  'P20963',
#  'Q15459',
#  'P35998',
#  'Q07666',
#  'P62330',
#  'O43390',
#  'Q9UPY3',
#  'O95433',
#  'Q8N6T7',
#  'Q12834',
#  'Q9NYF8',
#  'Q99615',
#  'P53007',
#  'P83105',
#  'P61962',
#  'P62269',
#  'P62280',
#  'P62633',
#  'Q92616',
#  'O00257',
#  'Q8IY92',
#  'Q9Y4X5',
#  'P62277',
#  'P62491',
#  'P35610',
#  'Q96H55',
#  'Q06124',
#  'P60842',
#  'Q92614',
#  'Q96JN8',
#  'Q15149',
#  'P26641',
#  'P49711',
#  'Q9UPN9',
#  'Q96PU5',
#  'Q7KZN9',
#  'P51991',
#  'Q04695',
#  'Q00653',
#  'Q07065',
#  'P47974',
#  'P62937',
#  'O75400',
#  'Q3ZCQ8',
#  'Q01105',
#  'P15498',
#  'Q13635',
#  'Q9Y5K5',
#  'P67870',
#  'Q92831',
#  'P31948',
#  'P61088',
#  'P56537',
#  'Q969P0',
#  'P40939',
#  'Q14204',
#  'P53621',
#  'P17066',
#  'P63279',
#  'Q9UQ80',
#  'P30050',
#  'P26599',
#  'O60264',
#  'Q06830',
#  'Q13469',
#  'O43791',
#  'P46779',
#  'Q99759',
#  'P51531',
#  'O15016',
#  'Q8NBF2',
#  'P16403',
#  'P38936',
#  'Q14247',
#  'P61513',
#  'Q93008',
#  'Q13043',
#  'Q13435',
#  'Q99986',
#  'Q7L2E3',
#  'P07237',
#  'P62913',
#  'Q9BQG0',
#  'Q15059',
#  'Q9Y478',
#  'P30101',
#  'P61313',
#  'Q6UY01',
#  'Q9NX58',
#  'Q16526',
#  'P62826',
#  'P11362',
#  'Q6PKG0',
#  'P01137',
#  'Q00005',
#  'P29350',
#  'Q9Y3I1',
#  'Q99873',
#  'Q9NZI8',
#  'O75807',
#  'Q3KP44',
#  'Q13813',
#  'P42345',
#  'Q03468',
#  'P42771',
#  'Q9NRI5',
#  'P46108',
#  'P35613',
#  'O14920',
#  'O00165',
#  'Q6ZW49',
#  'P51608',
#  'Q9Y5B9',
#  'P55036',
#  'Q13309',
#  'Q96PK6',
#  'Q00325',
#  'P39019',
#  'P17931',
#  'P62837',
#  'P62304',
#  'P63261',
#  'Q8N163',
#  'P62249',
#  'P04843',
#  'Q15393',
#  'P55209',
#  'P17813',
#  'P54274',
#  'O43318',
#  'P16220',
#  'P25205',
#  'P51784',
#  'P25490',
#  'Q9H2C0',
#  'P51149',
#  'Q07955',
#  'P34931',
#  'Q9C0C7',
#  'O60884',
#  'P50897',
#  'Q13485',
#  'P14618',
#  'P62906',
#  'P51858',
#  'P49336',
#  'P01116',
#  'P46777',
#  'P15924',
#  'Q96GG9',
#  'O00303',
#  'Q13011',
#  'P30876',
#  'Q8IYB3',
#  'Q92844',
#  'Q9UJV9',
#  'Q03112',
#  'Q9UNP9',
#  'P08865',
#  'P46781',
#  'Q01968',
#  'O75367',
#  'Q9BXB1',
#  'P46531',
#  'P61289',
#  'Q96AJ1',
#  'Q562R1',
#  'P37231',
#  'Q9UBS0',
#  'Q9H9B4',
#  'P37840',
#  'Q01196',
#  'Q08380',
#  'Q13310',
#  'O95376',
#  'Q96J02',
#  'Q96T76',
#  'Q9UL18',
#  'P61326',
#  'O00468',
#  'P12236',
#  'Q02543',
#  'P27708',
#  'Q5SW79',
#  'B4DJ51',
#  'Q99558',
#  'P52292',
#  'Q9UHD2',
#  'P49411',
#  'P62829',
#  'Q9Y2W1',
#  'Q99728',
#  'Q04837',
#  'O75208',
#  'P07550',
#  'O00213',
#  'P05388',
#  'Q13185',
#  'Q8IY34',
#  'Q15370',
#  'P49327',
#  'P25440',
#  'Q9HBL8',
#  'P31040',
#  'P63167',
#  'O00429',
#  'O43143',
#  'P56545',
#  'P62701',
#  'O94776',
#  'P24385',
#  'P62750',
#  'Q9NR30',
#  'P15336',
#  'Q9UMS4',
#  'Q9H9S0',
#  'Q7Z2W4',
#  'Q99497',
#  'P36897',
#  'Q92841',
#  'P13639',
#  'Q15287',
#  'P62424',
#  'Q9Y5Q3',
#  'P52597',
#  'P14923',
#  'P19438',
#  'Q9BV73',
#  'O75533',
#  'Q96AG4',
#  'P04049',
#  'P07910',
#  'O14744',
#  'P14625',
#  'P68371',
#  'P62917',
#  'Q9BVS5',
#  'O15027',
#  'P26373',
#  'P42224',
#  'Q9P0N5',
#  'P23508',
#  'P61586',
#  'P50914',
#  'P62888',
#  'Q9UNN5',
#  'P18124',
#  'P25788',
#  'P39023',
#  'Q8N4V1',
#  'Q96EA4',
#  'Q99714',
#  'P11387',
#  'P17980',
#  'Q99623',
#  'Q96CW1',
#  'Q15051',
#  'P45973',
#  'Q05513',
#  'O75489',
#  'Q13200',
#  'P62195',
#  'Q92785',
#  'P21860',
#  'O75386',
#  'O60341',
#  'Q9UL15',
#  'Q9H000',
#  'P36578',
#  'Q13127',
#  'Q92900',
#  'Q92804',
#  'Q96ST3',
#  'P42704',
#  'O75643',
#  'P29590',
#  'Q86U44',
#  'Q14203',
#  'Q99608',
#  'P07948',
#  'Q16576',
#  'P49023',
#  'P48729',
#  'Q12824',
#  'P50402',
#  'Q96B97',
#  'Q96RS6',
#  'P02768',
#  'Q8N122',
#  'Q9UBX2',
#  'P19784',
#  'Q14683',
#  'O60216',
#  'P06400',
#  'O15379',
#  'P06493',
#  'Q9P0L0',
#  'P78362',
#  'P0DMV9',
#  'P68363',
#  'Q15554',
#  'P35240',
#  'P61964',
#  'Q8N884',
#  'Q15796',
#  'Q13418',
#  'P07355',
#  'Q03135',
#  'Q86V81',
#  'P28482',
#  'P61221',
#  'P63244',
#  'Q9C0B0',
#  'Q14197',
#  'P22626',
#  'O00483',
#  'P10398',
#  'P51532',
#  'P06241',
#  'P22681',
#  'O75665',
#  'Q9UQE7',
#  'P61247',
#  'P40763',
#  'P06576',
#  'Q16643',
#  'Q9UI95',
#  'O00159',
#  'Q9NWT8',
#  'P08047',
#  'Q9NZQ7',
#  'Q15154',
#  'P46379',
#  'P00441',
#  'Q96CS3',
#  'P62263',
#  'O15155',
#  'P0CG47',
#  'P52298',
#  'P15880',
#  'Q6ZU80',
#  'Q9UGI8',
#  'Q07020',
#  'Q96GX1',
#  'Q7L5N1',
#  'Q9BY14',
#  'Q15006',
#  'P48643',
#  'P04406',
#  'Q15118',
#  'P01375',
#  'P49427',
#  'P20339',
#  'Q12906',
#  'Q6P1J9',
#  'P68366',
#  'P13693',
#  'Q9BQA1',
#  'P62807',
#  'P09429',
#  'P52272',
#  'Q05086',
#  'P29353',
#  'Q12905',
#  'Q8NC51',
#  'P23258',
#  'Q6NUN9',
#  'O00571',
#  'Q969H0',
#  'P23246',
#  'P33992',
#  'P55317',
#  'P49407',
#  'P05141',
#  'P08670',
#  'Q8N766',
#  'O95816',
#  'Q12933',
#  'Q9UQ35',
#  'Q15233',
#  'Q01844',
#  'P47755',
#  'Q09028',
#  'P21796',
#  'P36957',
#  'P68104',
#  'P11441',
#  'P25705',
#  'P68400',
#  'Q16543',
#  'Q01995',
#  'Q02878',
#  'P23396',
#  'Q96EB6',
#  'P50990',
#  'P27986',
#  'O95758',
#  'P09467',
#  'Q9P2P5',
#  'P15311',
#  'P67775',
#  'O15118',
#  'Q9BQE3',
#  'P63000',
#  'P31689',
#  'P57078',
#  'P33993',
#  'P61978',
#  'Q96SB4',
#  'Q08211',
#  'O14965',
#  'Q16659',
#  'O00567',
#  'Q9BQ67',
#  'P62140',
#  'P50991',
#  'P62241',
#  'P08559',
#  'O95696',
#  'Q8TAD8',
#  'P31947',
#  'Q9Y4E8',
#  'P40227',
#  'Q53F19',
#  'P63208',
#  'Q6NUS6',
#  'Q9UHB6',
#  'Q99832',
#  'P84022',
#  'P33778',
#  'P31749',
#  'Q9NVI7',
#  'Q96EP0',
#  'O14880',
#  'Q9Y297',
#  'P38919',
#  'Q13838',
#  'P68032',
#  'Q01860',
#  'Q9H4D1',
#  'P42858',
#  'P17844',
#  'P06733',
#  'P17987',
#  'Q5T7N2',
#  'Q12800',
#  'Q92793',
#  'P53350',
#  'Q9NWT6',
#  'Q14676',
#  'P56524',
#  'Q15843',
#  'Q9Y2I6',
#  'P11940',
#  'Q9HCE5',
#  'O95071',
#  'Q9H967',
#  'P04626',
#  'P0DP23',
#  'P24928',
#  'Q9UBN7',
#  'Q96C86',
#  'Q09161',
#  'Q86UK7',
#  'Q9H1C4',
#  'O60506',
#  'Q9UQL6',
#  'Q9HCE7',
#  'P11279',
#  'P01889',
#  'Q6K0P9',
#  'Q14974',
#  'Q07021',
#  'P21333',
#  'P12004',
#  'P04792',
#  'Q13509',
#  'Q9UKV8',
#  'P0DMV8',
#  'O94972',
#  'Q504Q3',
#  'Q16665',
#  'P13010',
#  'P49368',
#  'P09622',
#  'P78371',
#  'Q15077',
#  'P46934',
#  'O95831',
#  'P04908',
#  'P30153',
#  'Q14103',
#  'Q9Y265',
#  'Q14164',
#  'P78527',
#  'P09874',
#  'P60709',
#  'O95714',
#  'Q13627',
#  'Q93009',
#  'Q9UNE7',
#  'P46940',
#  'Q00610',
#  'P38646',
#  'Q96FW1',
#  'Q16531',
#  'Q9Y230',
#  'P07437',
#  'P54252',
#  'Q9NPJ6',
#  'P43243',
#  'Q86X19',
#  'O95994',
#  'P32121',
#  'P26368',
#  'P12956',
#  'Q13148',
#  'P54578',
#  'Q9NS91',
#  'P12931',
#  'P62877',
#  'O00487',
#  'Q9UKB1',
#  'P42166',
#  'P35226',
#  'P34932',
#  'Q12986',
#  'P35579',
#  'P05161',
#  'P22087',
#  'P35244',
#  'P27635',
#  'Q93034',
#  'P19838',
#  'Q12888',
#  'P60033',
#  'P16104',
#  'P19320',
#  'Q15365',
#  'P62753',
#  'Q04206',
#  'P60953',
#  'P04156',
#  'Q8IVT5',
#  'P18146',
#  'Q9Y6K9',
#  'O43493',
#  'Q9BRS2',
#  'P49841',
#  'Q9GZQ8',
#  'P02545',
#  'Q13617',
#  'Q9NZC7',
#  'P19338',
#  'P15927',
#  'P01308',
#  'P34897',
#  'Q9H492',
#  'O95817',
#  'Q13620',
#  'O95863',
#  'Q00987',
#  'P13612',
#  'Q8TB96',
#  'Q9C0B5',
#  'P67809',
#  'P46013',
#  'Q9UHD9',
#  'Q8TB24',
#  'O75530',
#  'P08238',
#  'P27694',
#  'P40337',
#  'Q13283',
#  'Q5JVF3',
#  'P62136',
#  'P48431',
#  'Q9NPI1',
#  'Q71U36',
#  'Q9BXM7',
#  'Q9H0R8',
#  'Q04917',
#  'P60520',
#  'P61081',
#  'Q14684',
#  'Q7Z6Z7',
#  'Q00839',
#  'Q13501',
#  'P51957',
#  'P62258',
#  'Q96GD4',
#  'P50750',
#  'P31946',
#  'P60484',
#  'P27824',
#  'Q96RK0',
#  'P35637',
#  'Q9H0W5',
#  'P10275',
#  'Q15022',
#  'P36873',
#  'Q9HBD1',
#  'Q9Y4K3',
#  'P09651',
#  'Q6P2Q9',
#  'Q5TC82',
#  'Q12873',
#  'P10636',
#  'P11021',
#  'Q9Y312',
#  'P63165',
#  'P46937',
#  'P10809',
#  'Q6IQ23',
#  'P61981',
#  'Q9H444',
#  'P24941',
#  'Q09472',
#  'Q96CF2',
#  'O60260',
#  'O60356',
#  'P27348',
#  'Q9NRD1',
#  'Q13573',
#  'Q13547',
#  'Q9NWS0',
#  'Q16666',
#  'P62993',
#  'Q14839',
#  'Q92769',
#  'Q99459',
#  'Q15910',
#  'P56945',
#  'Q8IWL3',
#  'Q9BXW9',
#  'Q13619',
#  'Q86VP6',
#  'O00308',
#  'P06748',
#  'Q676U5',
#  'Q9NRC8',
#  'P68431',
#  'P02751',
#  'Q99496',
#  'Q13616',
#  'Q5XPI4',
#  'P35222',
#  'Q9NQC7',
#  'Q14999',
#  'O95793',
#  'P55072',
#  'Q7L2J0',
#  'Q86VM9',
#  'Q15004',
#  'Q9H8V3',
#  'O15294',
#  'O75147',
#  'P08621',
#  'Q14498',
#  'O94992',
#  'P63104',
#  'O43663',
#  'Q4G0J3',
#  'Q8NFZ5',
#  'O94874',
#  'P35232',
#  'Q02241',
#  'P49736',
#  'Q9NQW6',
#  'Q6UX01',
#  'Q92905',
#  'P38398',
#  'P07900',
#  'P11142',
#  'O95235',
#  'P27695',
#  'Q9HCE1',
#  'Q13263',
#  'P13569',
#  'Q9UBU9',
#  'Q96HY6',
#  'P31943',
#  'Q13618',
#  'O14980',
#  'Q9H6Z9',
#  'P78317',
#  'Q13489',
#  'P61956',
#  'O60885',
#  'O94761',
#  'P49116',
#  'Q15029',
#  'P00533',
#  'O14578',
#  'P05412',
#  'P14866',
#  'P62805',
#  'O95786',
#  'Q15058',
#  'P04637',
#  'Q15717',
#  'P04629',
#  'P01106',
#  'Q5S007',
#  'Q14258',
#  'P03372',
#  'P05067',
#  'Q92731',
#  'Q69YN4',
#  'Q9H4M7',
#  'P0CG48']

# %%
len(bb)
# Out:
# 910
